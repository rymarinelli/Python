# %% [markdown]
# <a href="https://colab.research.google.com/github/rymarinelli/Python/blob/master/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import datasets, transforms

# %%
# !git clone https://github.com/IBM/CrossViT
# !cd CrossViT/
# Out:
# Cloning into 'CrossViT'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 64 (delta 24), reused 43 (delta 13), pack-reused 0
# Unpacking objects: 100% (64/64), done.

# %%
# !pip install -r /content/CrossViT/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 776.8 MB 18 kB/s
# ...
#      |████████████████████████████████| 12.8 MB 17.7 MB/s
# ...
#      |████████████████████████████████| 376 kB 45.5 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 70 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 41.1 MB/s
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220119-py3-none-any.whl size=65267 sha256=f02ac0f5b82d7cb47f977c8c520fdaa7fc97fbeafc1422d288e4e238cacb9792
#   Stored in directory: /root/.cache/pip/wheels/f3/b8/eb/61ed840f80d7198725bc061872b6019a7b3e9db4dbadf68083
# Successfully built fvcore
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
#!unzip /content/Transformer.zip
#dataset = datasets.ImageFolder("/content/Transformer")
#!python -m torch.distributed.launch --nproc_per_node=1 --use_env /content/CrossViT/main.py --model crossvit_9_dagger_224 --batch-size 16 --data-path /content/Transformer
# Out:
# Archive:  /content/Transformer.zip
#    creating: Transformer/train/
#    creating: Transformer/train/Fire/
#   inflating: Transformer/train/Fire/fire000.png
#   inflating: Transformer/train/Fire/fire001.png
#   inflating: Transformer/train/Fire/fire002.png
#   inflating: Transformer/train/Fire/fire003.png
#   inflating: Transformer/train/Fire/fire004.png
#   inflating: Transformer/train/Fire/fire005.png
#   inflating: Transformer/train/Fire/fire006.png
#   inflating: Transformer/train/Fire/fire007.png
#   inflating: Transformer/train/Fire/fire008.png
#   inflating: Transformer/train/Fire/fire009.png
#   inflating: Transformer/train/Fire/fire010.png
#   inflating: Transformer/train/Fire/fire011.png
#   inflating: Transformer/train/Fire/fire012.png
#   inflating: Transformer/train/Fire/fire013.png
#   inflating: Transformer/train/Fire/fire014.png
#   inflating: Transformer/train/Fire/fire015.png
#   inflating: Transformer/train/Fire/fire016.png
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 --use_env /content/CrossViT/main.py --model crossvit_9_dagger_224  --data-path /content/imagenet
# Out:
# | distributed init (rank 0): env://
# ...

# %%
# !unzip /content/imagenet.zip
# Out:
# Archive:  /content/imagenet.zip
#    creating: imagenet/train/
#    creating: imagenet/train/fire/
#   inflating: imagenet/train/fire/fire000.png
#   inflating: imagenet/train/fire/fire001.png
#   inflating: imagenet/train/fire/fire002.png
#   inflating: imagenet/train/fire/fire003.png
#   inflating: imagenet/train/fire/fire004.png
#   inflating: imagenet/train/fire/fire005.png
#   inflating: imagenet/train/fire/fire006.png
#   inflating: imagenet/train/fire/fire007.png
#   inflating: imagenet/train/fire/fire008.png
#   inflating: imagenet/train/fire/fire009.png
#   inflating: imagenet/train/fire/fire010.png
#   inflating: imagenet/train/fire/fire011.png
#   inflating: imagenet/train/fire/fire012.png
#   inflating: imagenet/train/fire/fire013.png
#   inflating: imagenet/train/fire/fire014.png
#   inflating: imagenet/train/fire/fire015.png
#   inflating: imagenet/train/fire/fire016.png
#   inflating: imagenet/train/fire/fire017.png
#   inflating: imagenet/train/fire/fire018.png
# ...

# %%
#model = torch.load('/content/CrossViT/models/model_best.pth')

# %%
# !unzip /content/imagenet.zip
# Out:
# Archive:  /content/imagenet.zip
#    creating: imagenet/train/
#    creating: imagenet/train/fire/
#   inflating: imagenet/train/fire/fire000.png
#   inflating: imagenet/train/fire/fire001.png
#   inflating: imagenet/train/fire/fire002.png
#   inflating: imagenet/train/fire/fire003.png
#   inflating: imagenet/train/fire/fire004.png
#   inflating: imagenet/train/fire/fire005.png
#   inflating: imagenet/train/fire/fire006.png
#   inflating: imagenet/train/fire/fire007.png
#   inflating: imagenet/train/fire/fire008.png
#   inflating: imagenet/train/fire/fire009.png
#   inflating: imagenet/train/fire/fire010.png
#   inflating: imagenet/train/fire/fire011.png
#   inflating: imagenet/train/fire/fire012.png
#   inflating: imagenet/train/fire/fire013.png
#   inflating: imagenet/train/fire/fire014.png
#   inflating: imagenet/train/fire/fire015.png
#   inflating: imagenet/train/fire/fire016.png
#   inflating: imagenet/train/fire/fire017.png
#   inflating: imagenet/train/fire/fire018.png
# ...
