# %% [markdown]
# <a href="https://colab.research.google.com/github/rymarinelli/Python/blob/master/Data_Poison_Radiology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Download Datasets

# %%
# %%capture
! wget https://s3.amazonaws.com/east1.public.rsna.org/AI/2017/Bone+Age+Training+Set.zip
! unzip /content/Bone+Age+Training+Set.zip
! wget https://www.rsna.org/-/media/Files/RSNA/Education/AI%20resources%20and%20training/AI%20image%20challenge/RSNA-2017-Pediatric-Bone-Age-Challenge-Dataset-Description.ashx?la=en&hash=A0B423007088816AFFACDCA934E2F09F903215F4&hash=A0B423007088816AFFACDCA934E2F09F903215F4
! wget https://s3.amazonaws.com/east1.public.rsna.org/AI/2017/Bone+Age+Training+Set+Annotations.zip
! unzip /content/Bone+Age+Training+Set+Annotations.zip

# %% [markdown]
# ## Get images into expected formats and within directories

# %%
import pandas as pd
import os


csv_file = 'train.csv'
df = pd.read_csv(csv_file)


image_dir = 'boneage-training-dataset'


def create_file_path(row):
    return os.path.join(image_dir, str(row['id']) + '.png')

# Apply to create file paths through the dataframe
df['file_path'] = df.apply(create_file_path, axis=1)

# Convert age to months (assuming it's already in months)
df['age_months'] = round(df['boneage']/30.25)

# Select only the required columns
df = df[['id', 'file_path', 'age_months']]

# %% [markdown]
# ## Create expected labels for YOLO

# %%
import os

# Updated mapping from age_months to class IDs
age_to_class_id = {0.0: 0, 1.0: 1, 2.0: 2, 3.0: 3, 4.0: 4, 5.0: 5, 6.0: 6, 7.0: 7, 8.0: 8}


label_dir = 'labels'
os.makedirs(label_dir, exist_ok=True)

# Iterate over the DataFrame rows
for index, row in df.iterrows():
    image_id = row['id']
    age_months = row['age_months']

    # Convert age_months to class ID using the mapping
    class_id = age_to_class_id[age_months]

    # Create the label file content for YOLO: class_id, center_x, center_y, width, height
    label_content = f"{class_id} 0.5 0.5 1 1"


    label_filename = f"{image_id}.txt"
    label_path = os.path.join(label_dir, label_filename)

    with open(label_path, 'w') as label_file:
        label_file.write(label_content)

# %% [markdown]
# ## Moving Labels and Images to fit expectations for YOLO

# %%
import os
import shutil
import random

def move_files(source_dir, image_dest_dir, label_source_dir, label_dest_dir, percent=0.8):
    if not os.path.exists(image_dest_dir):
        os.makedirs(image_dest_dir)
    if not os.path.exists(label_dest_dir):
        os.makedirs(label_dest_dir)


    png_files = [f for f in os.listdir(source_dir) if f.endswith('.png') and f[:-4].isdigit()]
    number_to_move = int(len(png_files) * percent)
    png_files_to_move = random.sample(png_files, number_to_move)

    moved_numbers = set()
    for file_name in png_files_to_move:
        shutil.move(os.path.join(source_dir, file_name), os.path.join(image_dest_dir, file_name))
        moved_numbers.add(file_name[:-4])

    # Move corresponding TXT files from common label source directory
    txt_files = [f for f in os.listdir(label_source_dir) if f.endswith('.txt') and f[:-4] in moved_numbers]
    for file_name in txt_files:
        shutil.move(os.path.join(label_source_dir, file_name), os.path.join(label_dest_dir, file_name))


source_images = '/content/boneage-training-dataset'
label_source = '/content/labels'
train_images_dir = '/content/datasets/bone_age/train/images'
train_labels_dir = "/content/datasets/bone_age/train/labels"
val_images_dir = '/content/datasets/bone_age/val/images'
val_labels_dir = "/content/datasets/bone_age/val/labels"

# Move files for training
moved_train_numbers = move_files(source_images, train_images_dir, label_source, train_labels_dir, percent=0.8)

# Remaining PNG files for validation
remaining_png_files = [f for f in os.listdir(source_images) if f.endswith('.png') and f[:-4].isdigit()]
remaining_numbers = {f[:-4] for f in remaining_png_files}


move_files(source_images, val_images_dir, label_source, val_labels_dir, percent=1.0)

# %%
# %%writefile bone_age_dataset.yaml
# train: /content/datasets/bone_age/train/images
# val: /content/datasets/bone_age/val/images
# nc: 9
# names: ['age_0_months', 'age_1_month', 'age_2_months', 'age_3_months', 'age_4_months', 'age_5_months', 'age_6_months', 'age_7_months', 'age_8_months']
# Out:
# Writing bone_age_dataset.yaml

# %% [markdown]
# # Detection Model

# %%
#!wget https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16953, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 16953 (delta 75), reused 98 (delta 48), pack-reused 16805 (from 1)
# Receiving objects: 100% (16953/16953), 15.71 MiB | 17.09 MiB/s, done.
# Resolving deltas: 100% (11608/11608), done.

# %%
# !pip install  ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.90-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.6-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.90-py3-none-any.whl (871 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 55.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.6-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.2.90 ultralytics-thop-2.0.6

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml").load("yolov8n.pt")  # build from YAML and transfer weights


results = model.train(data="/content/bone_age_dataset.yaml", epochs=10, imgsz=640)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 252MB/s]
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=/content/bone_age_dataset.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=yolov8n.pt, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 143MB/s]
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753067  ultralytics.nn.modules.head.Detect           [9, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3,012,603 parameters, 3,012,587 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/bone_age/train/labels... 10088 images, 0 backgrounds, 0 corrupt: 100%|██████████| 10088/10088 [00:12<00:00, 813.93it/s]
# train: New cache created: /content/datasets/bone_age/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/datasets/bone_age/val/labels... 2523 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2523/2523 [00:03<00:00, 664.25it/s]
# val: New cache created: /content/datasets/bone_age/val/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      2.37G     0.2089      2.301          1          8        640: 100%|██████████| 631/631 [01:18<00:00,  8.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:14<00:00,  5.27it/s]
#                    all       2523       2523      0.585      0.636      0.439      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      2.25G    0.08979      1.268     0.8891          8        640: 100%|██████████| 631/631 [01:13<00:00,  8.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.21it/s]
#                    all       2523       2523      0.631      0.639      0.535      0.535
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      2.25G    0.07847       1.03     0.8784          8        640: 100%|██████████| 631/631 [01:12<00:00,  8.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.33it/s]
#                    all       2523       2523      0.476      0.739      0.504      0.504
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      2.24G    0.06692      0.928     0.8761          8        640: 100%|██████████| 631/631 [01:12<00:00,  8.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.16it/s]
#                    all       2523       2523      0.543      0.787      0.557      0.555
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      2.24G    0.05997     0.8689     0.8759          8        640: 100%|██████████| 631/631 [01:11<00:00,  8.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.35it/s]
#                    all       2523       2523      0.587      0.724      0.574      0.574
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      2.24G    0.04993     0.8464     0.8698          8        640: 100%|██████████| 631/631 [01:11<00:00,  8.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.16it/s]
#                    all       2523       2523      0.692      0.645       0.59      0.589
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      2.24G    0.04267     0.8054     0.8665          8        640: 100%|██████████| 631/631 [01:11<00:00,  8.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.14it/s]
#                    all       2523       2523      0.548      0.811      0.562      0.561
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      2.24G    0.03778     0.7783     0.8634          8        640: 100%|██████████| 631/631 [01:11<00:00,  8.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.44it/s]
#                    all       2523       2523        0.6      0.695       0.59      0.589
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      2.24G        inf     0.7529     0.8662          8        640: 100%|██████████| 631/631 [01:11<00:00,  8.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.17it/s]
#                    all       2523       2523      0.598      0.738      0.607      0.606
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      2.24G    0.02778     0.7218     0.8609          8        640: 100%|██████████| 631/631 [01:13<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:12<00:00,  6.09it/s]
#                    all       2523       2523      0.574      0.736       0.63      0.628
# 10 epochs completed in 0.241 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8n summary (fused): 168 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 79/79 [00:14<00:00,  5.58it/s]
#                    all       2523       2523      0.574      0.736       0.63      0.629
#           age_0_months          6          6      0.157      0.333      0.246      0.238
#            age_1_month         91         91      0.712      0.895      0.834      0.833
#           age_2_months        199        199      0.582      0.955      0.797      0.797
#           age_3_months        358        358      0.546       0.86      0.722      0.722
#           age_4_months        645        645      0.556      0.874      0.688      0.688
#           age_5_months        785        785      0.591      0.954      0.775      0.775
#           age_6_months        372        372      0.583      0.871       0.81      0.809
#           age_7_months         61         61      0.442      0.885      0.625      0.625
#           age_8_months          6          6          1          0      0.172      0.172
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

metrics = model.val()
print(f"Adversarial mAP50-95: {metrics.box.map}")
print(f"Adversarial mAP50: {metrics.box.map50}")
print(f"Adversarial mAP75: {metrics.box.map75}")
print(f"Adversarial mAPs per category: {metrics.box.maps}")
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8n summary (fused): 168 layers, 3,007,403 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/bone_age/val/labels.cache... 2523 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2523/2523 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 158/158 [00:18<00:00,  8.52it/s]
#                    all       2523       2523      0.604      0.692      0.627      0.626
#           age_0_months          6          6      0.107      0.167      0.227      0.221
#            age_1_month         91         91      0.751      0.879      0.832      0.832
#           age_2_months        199        199      0.646      0.925        0.8        0.8
#           age_3_months        358        358      0.585      0.818      0.721      0.721
#           age_4_months        645        645      0.589      0.825      0.688      0.687
#           age_5_months        785        785      0.618      0.928      0.775      0.775
#           age_6_months        372        372      0.674      0.833       0.81      0.809
#           age_7_months         61         61      0.465      0.852      0.617      0.617
#           age_8_months          6          6          1          0      0.171      0.171
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val
# Adversarial mAP50-95: 0.6258917655956994
# Adversarial mAP50: 0.6266720517540272
# Adversarial mAP75: 0.6266688614089096
# Adversarial mAPs per category: [    0.22095     0.83168     0.79964     0.72091     0.68749     0.77502     0.80948     0.61653     0.17132]

# %% [markdown]
# # Data Poisoning

# %% [markdown]
# ## Creates FGSM examples

# %%
import torch
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


model = YOLO("runs/detect/train/weights/best.pt")
model.model.to(device)


original_image_dir = '/content/datasets/bone_age/train/images'
ground_truth_labels_dir = '/content/datasets/bone_age/train/labels'

# adversarial images
adv_image_dir = '/content/datasets/bone_age/train/adversarial_images'


if not os.path.exists(original_image_dir):
    raise FileNotFoundError(f"Original image directory does not exist: {original_image_dir}")
if not os.path.exists(ground_truth_labels_dir):
    raise FileNotFoundError(f"Ground truth labels directory does not exist: {ground_truth_labels_dir}")
if not os.path.exists(adv_image_dir):
    os.makedirs(adv_image_dir)

# Define the transformation for the images
transform = transforms.Compose([
    transforms.Resize((416, 416)),
    transforms.ToTensor(),
])

# dataset class to handle images without class folders
class OriginalDataset(Dataset):
    def __init__(self, image_dir, label_dir, transform=None):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.transform = transform
        self.image_names = os.listdir(image_dir)

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        img_path = os.path.join(self.image_dir, img_name)
        label_path = os.path.join(self.label_dir, img_name.replace('.png', '.txt'))

        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        labels = self.load_labels(label_path)
        return image, labels, img_name

    @staticmethod
    def load_labels(label_path):
        with open(label_path, 'r') as f:
            labels = f.readlines()
        # Convert labels
        labels = [list(map(float, label.strip().split())) for label in labels]
        return labels

# Load the original dataset
original_dataset = OriginalDataset(original_image_dir, ground_truth_labels_dir, transform=transform)
data_loader = DataLoader(original_dataset, batch_size=1, shuffle=False)

#  Apply FGSM attack on an image
def fgsm_attack(image, epsilon, data_grad):
    sign_data_grad = data_grad.sign()
    perturbed_image = image + epsilon * sign_data_grad
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    return perturbed_image

# Parameters for FGSM
epsilon = 8 / 255

# Generate adversarial examples and evaluate the model
true_positives, false_positives, false_negatives = 0, 0, 0

for img, ground_truth, img_name in data_loader:
    # Ensure img_name is a string
    if isinstance(img_name, tuple):
        img_name = img_name[0]

    # Check if the adversarial image already exists
    adv_img_path = os.path.join(adv_image_dir, img_name)
    if os.path.exists(adv_img_path):
        continue

    img = img.to(device)
    ground_truth = [torch.tensor(item).clone().detach().requires_grad_(False).to(device) for sublist in ground_truth for item in sublist]

    img.requires_grad = True
    outputs = model.model(img)
    loss = outputs[0][0].sum()

    model.model.zero_grad()
    loss.backward()

    data_grad = img.grad.data
    perturbed_img = fgsm_attack(img, epsilon, data_grad)

    # Save the adversarial image
    adv_image_np = perturbed_img.squeeze().detach().cpu().numpy().transpose(1, 2, 0) * 255
    adv_image_np = adv_image_np.astype(np.uint8)
    adv_image = Image.fromarray(adv_image_np)
    adv_image.save(adv_img_path)

    adv_outputs = model.model(perturbed_img)

    # Compare adv_outputs with ground_truth to calculate TP, FP, FN
    for pred in adv_outputs[0]:
        pred = torch.tensor(pred.tolist()).to(device)  # Ensure prediction is a tensor on the same device
        if any(torch.all(torch.eq(pred, gt)) for gt in ground_truth):
            true_positives += 1
        else:
            false_positives += 1
    for gt in ground_truth:
        if not any(torch.all(torch.eq(gt, pred)) for pred in adv_outputs[0]):
            false_negatives += 1

# Calculate precision, recall, and F1 score
precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# Print accuracy metrics
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1_score}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c8897d459ddb> in <cell line: 7>()
#       5 import os
#       6 import numpy as np
# ----> 7 from ultralytics import YOLO
#       8 import shutil
#       9
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Creates C&W Examples

# %%
from ultralytics import YOLO


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = YOLO("runs/detect/train/weights/best.pt")
model.model.to(device)  # Ensure the model's weights are moved to GPU


dataset_config = '/content/bone_age_dataset.yaml'


results = model.val(data=dataset_config, split='val', device=device)

# Print the results
#print("mAP@0.5:", results.results_dict['metrics/mAP_0.5'])
#print("mAP@0.5:0.95:", results.results_dict['metrics/mAP_0.5:0.95'])

# %% [markdown]
# # Defense Distillation

# %%
from ultralytics import YOLO
import os
import numpy as np
from glob import glob
import json
from ultralytics import YOLO

# Load the teacher model
teacher_model = YOLO("/content/runs/detect/train/weights/best.pt")


train_image_dir = "/content/datasets/bone_age/train/images"


def list_images(directory, extensions=('jpg', 'jpeg', 'png')):
    images = []
    for ext in extensions:
        images.extend(glob(os.path.join(directory, f'*.{ext}')))
    return images

train_image_paths = list_images(train_image_dir)

print(f"Found {len(train_image_paths)} training images.")

# Dictionary to store image paths and their classes and confidence scores
image_predictions_mapping = {}

# extract the first class and confidence score
def extract_predictions(model, image_path):
    results = model(image_path)  # run inference on the image
    if len(results[0].boxes) > 0:
        boxes = results[0].boxes.data.cpu().numpy()  # get predictions and convert to numpy array
        first_class = int(boxes[0, 5])  # extract the first class
        first_confidence = float(boxes[0, 4])  # extract the first confidence score
        return first_class, first_confidence
    else:
        return None, None


for img_path in train_image_paths:
    first_class, first_confidence = extract_predictions(teacher_model, img_path)
    if first_class is not None:
        image_predictions_mapping[img_path] = {
            "class": first_class,
            "confidence": first_confidence
        }  # store as list for JSON serialization

# Save the mapping to a JSON file
with open('train_image_predictions_mapping.json', 'w') as f:
    json.dump(image_predictions_mapping, f)

# Print out the mapping for verification
for img_path, predictions in image_predictions_mapping.items():
    print(f"Image: {img_path}, Class: {predictions['class']}, Confidence: {predictions['confidence']}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Image: /content/datasets/bone_age/train/images/9155.png, Class: 5, Confidence: 0.8035032749176025
# Image: /content/datasets/bone_age/train/images/10253.png, Class: 4, Confidence: 0.7304187417030334
# Image: /content/datasets/bone_age/train/images/15365.png, Class: 4, Confidence: 0.694675862789154
# Image: /content/datasets/bone_age/train/images/4857.png, Class: 6, Confidence: 0.5818771123886108
# Image: /content/datasets/bone_age/train/images/7760.png, Class: 5, Confidence: 0.5964787006378174
# Image: /content/datasets/bone_age/train/images/1560.png, Class: 3, Confidence: 0.7223576307296753
# Image: /content/datasets/bone_age/train/images/10293.png, Class: 5, Confidence: 0.6403976082801819
# Image: /content/datasets/bone_age/train/images/7651.png, Class: 5, Confidence: 0.6597110629081726
# Image: /content/datasets/bone_age/train/images/8790.png, Class: 4, Confidence: 0.6370729207992554
# Image: /content/datasets/bone_age/train/images/6344.png, Class: 6, Confidence: 0.6003376245498657
# Image: /content/datasets/bone_age/train/images/8518.png, Class: 3, Confidence: 0.7644906640052795
# Image: /content/datasets/bone_age/train/images/11604.png, Class: 5, Confidence: 0.6837892532348633
# Image: /content/datasets/bone_age/train/images/13880.png, Class: 5, Confidence: 0.6165220737457275
# Image: /content/datasets/bone_age/train/images/4882.png, Class: 4, Confidence: 0.7304080724716187
# Image: /content/datasets/bone_age/train/images/5029.png, Class: 1, Confidence: 0.5229333639144897
# Image: /content/datasets/bone_age/train/images/9481.png, Class: 5, Confidence: 0.7864950299263
# Image: /content/datasets/bone_age/train/images/13914.png, Class: 4, Confidence: 0.6379052400588989
# Image: /content/datasets/bone_age/train/images/1818.png, Class: 7, Confidence: 0.5780377984046936
# Image: /content/datasets/bone_age/train/images/8426.png, Class: 5, Confidence: 0.8154463768005371
# Image: /content/datasets/bone_age/train/images/6229.png, Class: 5, Confidence: 0.7225177884101868
# Image: /content/datasets/bone_age/train/images/5985.png, Class: 5, Confidence: 0.7965232133865356
# Image: /content/datasets/bone_age/train/images/9771.png, Class: 3, Confidence: 0.5779027938842773
# Image: /content/datasets/bone_age/train/images/2614.png, Class: 5, Confidence: 0.5944855213165283
# Image: /content/datasets/bone_age/train/images/9142.png, Class: 4, Confidence: 0.6233175992965698
# Image: /content/datasets/bone_age/train/images/5628.png, Class: 6, Confidence: 0.8677024245262146
# Image: /content/datasets/bone_age/train/images/5861.png, Class: 6, Confidence: 0.6665710210800171
# Image: /content/datasets/bone_age/train/images/13715.png, Class: 6, Confidence: 0.8598062992095947
# Image: /content/datasets/bone_age/train/images/3676.png, Class: 5, Confidence: 0.7102051973342896
# Image: /content/datasets/bone_age/train/images/12601.png, Class: 6, Confidence: 0.6709235310554504
# Image: /content/datasets/bone_age/train/images/15234.png, Class: 4, Confidence: 0.6810753345489502
# Image: /content/datasets/bone_age/train/images/13518.png, Class: 2, Confidence: 0.8080862760543823
# Image: /content/datasets/bone_age/train/images/11042.png, Class: 6, Confidence: 0.7720202803611755
# Image: /content/datasets/bone_age/train/images/10502.png, Class: 3, Confidence: 0.6651938557624817
# Image: /content/datasets/bone_age/train/images/10246.png, Class: 3, Confidence: 0.6919620633125305
# Image: /content/datasets/bone_age/train/images/14379.png, Class: 2, Confidence: 0.605514407157898
# Image: /content/datasets/bone_age/train/images/8320.png, Class: 5, Confidence: 0.5742074251174927
# Image: /content/datasets/bone_age/train/images/4694.png, Class: 5, Confidence: 0.832368016242981
# Image: /content/datasets/bone_age/train/images/12659.png, Class: 5, Confidence: 0.832663893699646
# Image: /content/datasets/bone_age/train/images/2733.png, Class: 4, Confidence: 0.5455180406570435
# Image: /content/datasets/bone_age/train/images/14473.png, Class: 5, Confidence: 0.6693885326385498
# Image: /content/datasets/bone_age/train/images/11519.png, Class: 5, Confidence: 0.6240264177322388
# Image: /content/datasets/bone_age/train/images/9941.png, Class: 7, Confidence: 0.30199480056762695
# Image: /content/datasets/bone_age/train/images/12123.png, Class: 5, Confidence: 0.7722224593162537
# Image: /content/datasets/bone_age/train/images/5968.png, Class: 2, Confidence: 0.6821836829185486
# Image: /content/datasets/bone_age/train/images/1781.png, Class: 2, Confidence: 0.6419784426689148
# Image: /content/datasets/bone_age/train/images/6516.png, Class: 5, Confidence: 0.7046716809272766
# Image: /content/datasets/bone_age/train/images/14002.png, Class: 5, Confidence: 0.7184833884239197
# Image: /content/datasets/bone_age/train/images/14998.png, Class: 5, Confidence: 0.6662894487380981
# Image: /content/datasets/bone_age/train/images/10472.png, Class: 4, Confidence: 0.5346686244010925
# Image: /content/datasets/bone_age/train/images/11528.png, Class: 7, Confidence: 0.5398750901222229
# Image: /content/datasets/bone_age/train/images/10522.png, Class: 3, Confidence: 0.7801216840744019
# Image: /content/datasets/bone_age/train/images/13995.png, Class: 4, Confidence: 0.6886863112449646
# Image: /content/datasets/bone_age/train/images/3230.png, Class: 4, Confidence: 0.6099787950515747
# Image: /content/datasets/bone_age/train/images/1911.png, Class: 5, Confidence: 0.8087691068649292
# Image: /content/datasets/bone_age/train/images/14628.png, Class: 4, Confidence: 0.6803239583969116
# Image: /content/datasets/bone_age/train/images/7162.png, Class: 5, Confidence: 0.8195058703422546
# Image: /content/datasets/bone_age/train/images/8396.png, Class: 5, Confidence: 0.7180289030075073
# Image: /content/datasets/bone_age/train/images/7158.png, Class: 3, Confidence: 0.3459726870059967
# Image: /content/datasets/bone_age/train/images/5719.png, Class: 5, Confidence: 0.8056193590164185
# Image: /content/datasets/bone_age/train/images/13573.png, Class: 1, Confidence: 0.7335573434829712
# Image: /content/datasets/bone_age/train/images/6370.png, Class: 4, Confidence: 0.7682685852050781
# Image: /content/datasets/bone_age/train/images/15354.png, Class: 5, Confidence: 0.6192286014556885
# Image: /content/datasets/bone_age/train/images/1567.png, Class: 3, Confidence: 0.5080407857894897
# Image: /content/datasets/bone_age/train/images/7550.png, Class: 5, Confidence: 0.7955713868141174
# Image: /content/datasets/bone_age/train/images/4247.png, Class: 5, Confidence: 0.3158687651157379
# Image: /content/datasets/bone_age/train/images/6989.png, Class: 4, Confidence: 0.6403988599777222
# Image: /content/datasets/bone_age/train/images/12929.png, Class: 4, Confidence: 0.7610962390899658
# Image: /content/datasets/bone_age/train/images/5832.png, Class: 6, Confidence: 0.7149121761322021
# Image: /content/datasets/bone_age/train/images/9352.png, Class: 7, Confidence: 0.6416320204734802
# Image: /content/datasets/bone_age/train/images/4599.png, Class: 5, Confidence: 0.7547760605812073
# Image: /content/datasets/bone_age/train/images/11094.png, Class: 4, Confidence: 0.5969988107681274
# Image: /content/datasets/bone_age/train/images/14735.png, Class: 4, Confidence: 0.6047110557556152
# Image: /content/datasets/bone_age/train/images/13137.png, Class: 5, Confidence: 0.7773690223693848
# Image: /content/datasets/bone_age/train/images/12744.png, Class: 4, Confidence: 0.5384252071380615
# Image: /content/datasets/bone_age/train/images/3056.png, Class: 5, Confidence: 0.42479443550109863
# Image: /content/datasets/bone_age/train/images/5754.png, Class: 6, Confidence: 0.8661512136459351
# Image: /content/datasets/bone_age/train/images/1746.png, Class: 2, Confidence: 0.7600906491279602
# Image: /content/datasets/bone_age/train/images/3265.png, Class: 5, Confidence: 0.6060364246368408
# Image: /content/datasets/bone_age/train/images/6484.png, Class: 4, Confidence: 0.5176289081573486
# Image: /content/datasets/bone_age/train/images/15309.png, Class: 3, Confidence: 0.5362187623977661
# Image: /content/datasets/bone_age/train/images/8487.png, Class: 4, Confidence: 0.8282998204231262
# Image: /content/datasets/bone_age/train/images/11157.png, Class: 5, Confidence: 0.7052629590034485
# Image: /content/datasets/bone_age/train/images/1517.png, Class: 4, Confidence: 0.4886787235736847
# Image: /content/datasets/bone_age/train/images/14951.png, Class: 2, Confidence: 0.8097449541091919
# Image: /content/datasets/bone_age/train/images/14676.png, Class: 3, Confidence: 0.579683244228363
# Image: /content/datasets/bone_age/train/images/6441.png, Class: 4, Confidence: 0.7557200789451599
# Image: /content/datasets/bone_age/train/images/6557.png, Class: 5, Confidence: 0.5658823847770691
# Image: /content/datasets/bone_age/train/images/4853.png, Class: 3, Confidence: 0.525445282459259
# Image: /content/datasets/bone_age/train/images/4159.png, Class: 4, Confidence: 0.6602203249931335
# Image: /content/datasets/bone_age/train/images/9272.png, Class: 4, Confidence: 0.7206258773803711
# Image: /content/datasets/bone_age/train/images/11175.png, Class: 2, Confidence: 0.8383650183677673
# Image: /content/datasets/bone_age/train/images/4602.png, Class: 4, Confidence: 0.6995810270309448
# Image: /content/datasets/bone_age/train/images/1435.png, Class: 6, Confidence: 0.6656595468521118
# Image: /content/datasets/bone_age/train/images/8177.png, Class: 4, Confidence: 0.7023392915725708
# Image: /content/datasets/bone_age/train/images/13533.png, Class: 2, Confidence: 0.7666608095169067
# Image: /content/datasets/bone_age/train/images/4883.png, Class: 2, Confidence: 0.7922148704528809
# Image: /content/datasets/bone_age/train/images/5473.png, Class: 4, Confidence: 0.6621814966201782
# Image: /content/datasets/bone_age/train/images/5447.png, Class: 6, Confidence: 0.8553930521011353
# Image: /content/datasets/bone_age/train/images/12058.png, Class: 4, Confidence: 0.6660933494567871
# Image: /content/datasets/bone_age/train/images/4245.png, Class: 4, Confidence: 0.6510979533195496
# Image: /content/datasets/bone_age/train/images/13236.png, Class: 5, Confidence: 0.8107990622520447
# Image: /content/datasets/bone_age/train/images/5246.png, Class: 2, Confidence: 0.7932195067405701
# Image: /content/datasets/bone_age/train/images/9350.png, Class: 5, Confidence: 0.7212634682655334
# Image: /content/datasets/bone_age/train/images/13003.png, Class: 4, Confidence: 0.5801712274551392
# Image: /content/datasets/bone_age/train/images/10204.png, Class: 5, Confidence: 0.5381002426147461
# Image: /content/datasets/bone_age/train/images/6996.png, Class: 5, Confidence: 0.7956730723381042
# Image: /content/datasets/bone_age/train/images/3315.png, Class: 3, Confidence: 0.6940596103668213
# Image: /content/datasets/bone_age/train/images/4100.png, Class: 6, Confidence: 0.5003998279571533
# Image: /content/datasets/bone_age/train/images/12353.png, Class: 6, Confidence: 0.6845398545265198
# Image: /content/datasets/bone_age/train/images/9140.png, Class: 6, Confidence: 0.8539659380912781
# Image: /content/datasets/bone_age/train/images/10483.png, Class: 4, Confidence: 0.6324520111083984
# Image: /content/datasets/bone_age/train/images/12698.png, Class: 4, Confidence: 0.6590275168418884
# Image: /content/datasets/bone_age/train/images/14837.png, Class: 5, Confidence: 0.6616288423538208
# Image: /content/datasets/bone_age/train/images/15389.png, Class: 7, Confidence: 0.47443369030952454
# Image: /content/datasets/bone_age/train/images/3614.png, Class: 4, Confidence: 0.5435262322425842
# Image: /content/datasets/bone_age/train/images/11700.png, Class: 5, Confidence: 0.634162962436676
# Image: /content/datasets/bone_age/train/images/6013.png, Class: 5, Confidence: 0.6234340667724609
# Image: /content/datasets/bone_age/train/images/8394.png, Class: 6, Confidence: 0.5451111197471619
# Image: /content/datasets/bone_age/train/images/11446.png, Class: 4, Confidence: 0.4570593237876892
# Image: /content/datasets/bone_age/train/images/11263.png, Class: 2, Confidence: 0.7733979225158691
# Image: /content/datasets/bone_age/train/images/3563.png, Class: 5, Confidence: 0.582473874092102
# Image: /content/datasets/bone_age/train/images/2066.png, Class: 5, Confidence: 0.783622682094574
# Image: /content/datasets/bone_age/train/images/13690.png, Class: 7, Confidence: 0.5678137540817261
# Image: /content/datasets/bone_age/train/images/14436.png, Class: 5, Confidence: 0.6059145927429199
# Image: /content/datasets/bone_age/train/images/7691.png, Class: 3, Confidence: 0.7842977046966553
# Image: /content/datasets/bone_age/train/images/7932.png, Class: 5, Confidence: 0.5698221325874329
# Image: /content/datasets/bone_age/train/images/15047.png, Class: 1, Confidence: 0.45574459433555603
# Image: /content/datasets/bone_age/train/images/13020.png, Class: 3, Confidence: 0.5460063815116882
# Image: /content/datasets/bone_age/train/images/11426.png, Class: 4, Confidence: 0.6941825151443481
# Image: /content/datasets/bone_age/train/images/12415.png, Class: 5, Confidence: 0.6088718771934509
# Image: /content/datasets/bone_age/train/images/8198.png, Class: 5, Confidence: 0.790283203125
# Image: /content/datasets/bone_age/train/images/13215.png, Class: 5, Confidence: 0.822361946105957
# Image: /content/datasets/bone_age/train/images/2400.png, Class: 6, Confidence: 0.6600345969200134
# Image: /content/datasets/bone_age/train/images/2005.png, Class: 3, Confidence: 0.7102388739585876
# Image: /content/datasets/bone_age/train/images/2333.png, Class: 6, Confidence: 0.6397659778594971
# Image: /content/datasets/bone_age/train/images/12522.png, Class: 4, Confidence: 0.6301795244216919
# Image: /content/datasets/bone_age/train/images/8248.png, Class: 4, Confidence: 0.7781912684440613
# Image: /content/datasets/bone_age/train/images/6935.png, Class: 3, Confidence: 0.6414453983306885
# Image: /content/datasets/bone_age/train/images/11064.png, Class: 5, Confidence: 0.7401846647262573
# Image: /content/datasets/bone_age/train/images/6982.png, Class: 5, Confidence: 0.6429919004440308
# Image: /content/datasets/bone_age/train/images/13151.png, Class: 4, Confidence: 0.6402685642242432
# Image: /content/datasets/bone_age/train/images/2509.png, Class: 5, Confidence: 0.6500743627548218
# Image: /content/datasets/bone_age/train/images/5381.png, Class: 4, Confidence: 0.766864538192749
# Image: /content/datasets/bone_age/train/images/2843.png, Class: 5, Confidence: 0.6719591617584229
# Image: /content/datasets/bone_age/train/images/11124.png, Class: 4, Confidence: 0.6801408529281616
# Image: /content/datasets/bone_age/train/images/2511.png, Class: 5, Confidence: 0.785466730594635
# Image: /content/datasets/bone_age/train/images/4312.png, Class: 7, Confidence: 0.5477153062820435
# Image: /content/datasets/bone_age/train/images/9484.png, Class: 3, Confidence: 0.4514293372631073
# Image: /content/datasets/bone_age/train/images/9480.png, Class: 5, Confidence: 0.7649305462837219
# Image: /content/datasets/bone_age/train/images/10928.png, Class: 4, Confidence: 0.6520838737487793
# Image: /content/datasets/bone_age/train/images/12771.png, Class: 4, Confidence: 0.6162573099136353
# Image: /content/datasets/bone_age/train/images/1553.png, Class: 6, Confidence: 0.7353420257568359
# Image: /content/datasets/bone_age/train/images/15198.png, Class: 6, Confidence: 0.7264456748962402
# Image: /content/datasets/bone_age/train/images/2705.png, Class: 3, Confidence: 0.6401160359382629
# Image: /content/datasets/bone_age/train/images/9976.png, Class: 1, Confidence: 0.7387101054191589
# Image: /content/datasets/bone_age/train/images/3127.png, Class: 5, Confidence: 0.5356489419937134
# Image: /content/datasets/bone_age/train/images/11059.png, Class: 5, Confidence: 0.7354640960693359
# Image: /content/datasets/bone_age/train/images/5073.png, Class: 3, Confidence: 0.7252281308174133
# Image: /content/datasets/bone_age/train/images/6079.png, Class: 6, Confidence: 0.8077870607376099
# Image: /content/datasets/bone_age/train/images/13675.png, Class: 5, Confidence: 0.7192258834838867
# Image: /content/datasets/bone_age/train/images/12329.png, Class: 3, Confidence: 0.712187647819519
# Image: /content/datasets/bone_age/train/images/11209.png, Class: 5, Confidence: 0.7752447724342346
# Image: /content/datasets/bone_age/train/images/8290.png, Class: 5, Confidence: 0.8450505137443542
# Image: /content/datasets/bone_age/train/images/13846.png, Class: 4, Confidence: 0.7139492630958557
# Image: /content/datasets/bone_age/train/images/8924.png, Class: 3, Confidence: 0.54976886510849
# Image: /content/datasets/bone_age/train/images/14307.png, Class: 5, Confidence: 0.8562015295028687
# Image: /content/datasets/bone_age/train/images/9351.png, Class: 6, Confidence: 0.7113037109375
# Image: /content/datasets/bone_age/train/images/10062.png, Class: 5, Confidence: 0.8173315525054932
# Image: /content/datasets/bone_age/train/images/10658.png, Class: 5, Confidence: 0.8099489212036133
# Image: /content/datasets/bone_age/train/images/12926.png, Class: 3, Confidence: 0.5995736122131348
# Image: /content/datasets/bone_age/train/images/7269.png, Class: 2, Confidence: 0.7861406207084656
# Image: /content/datasets/bone_age/train/images/9192.png, Class: 5, Confidence: 0.7063729166984558
# Image: /content/datasets/bone_age/train/images/3133.png, Class: 3, Confidence: 0.5405901670455933
# Image: /content/datasets/bone_age/train/images/2113.png, Class: 5, Confidence: 0.7377331256866455
# Image: /content/datasets/bone_age/train/images/15131.png, Class: 4, Confidence: 0.691470205783844
# Image: /content/datasets/bone_age/train/images/9943.png, Class: 2, Confidence: 0.7610844373703003
# Image: /content/datasets/bone_age/train/images/6656.png, Class: 3, Confidence: 0.6013776659965515
# Image: /content/datasets/bone_age/train/images/15026.png, Class: 4, Confidence: 0.7069622278213501
# Image: /content/datasets/bone_age/train/images/14277.png, Class: 3, Confidence: 0.6114832758903503
# Image: /content/datasets/bone_age/train/images/13963.png, Class: 4, Confidence: 0.7062106728553772
# Image: /content/datasets/bone_age/train/images/5482.png, Class: 2, Confidence: 0.6201208829879761
# Image: /content/datasets/bone_age/train/images/5763.png, Class: 5, Confidence: 0.7366796731948853
# Image: /content/datasets/bone_age/train/images/6289.png, Class: 3, Confidence: 0.6212233901023865
# Image: /content/datasets/bone_age/train/images/11613.png, Class: 2, Confidence: 0.7815431356430054
# Image: /content/datasets/bone_age/train/images/14450.png, Class: 4, Confidence: 0.7346118688583374
# Image: /content/datasets/bone_age/train/images/15285.png, Class: 3, Confidence: 0.7575856447219849
# Image: /content/datasets/bone_age/train/images/5932.png, Class: 6, Confidence: 0.6430627107620239
# Image: /content/datasets/bone_age/train/images/2699.png, Class: 6, Confidence: 0.4494243562221527
# Image: /content/datasets/bone_age/train/images/11588.png, Class: 4, Confidence: 0.6863291263580322
# Image: /content/datasets/bone_age/train/images/8583.png, Class: 4, Confidence: 0.7254922389984131
# Image: /content/datasets/bone_age/train/images/14567.png, Class: 5, Confidence: 0.802954912185669
# Image: /content/datasets/bone_age/train/images/12720.png, Class: 5, Confidence: 0.7442440390586853
# Image: /content/datasets/bone_age/train/images/6000.png, Class: 2, Confidence: 0.843109130859375
# Image: /content/datasets/bone_age/train/images/2613.png, Class: 5, Confidence: 0.784260630607605
# Image: /content/datasets/bone_age/train/images/13363.png, Class: 2, Confidence: 0.713923990726471
# Image: /content/datasets/bone_age/train/images/4648.png, Class: 6, Confidence: 0.6044601202011108
# Image: /content/datasets/bone_age/train/images/5531.png, Class: 6, Confidence: 0.5834073424339294
# Image: /content/datasets/bone_age/train/images/13793.png, Class: 5, Confidence: 0.8021844625473022
# Image: /content/datasets/bone_age/train/images/7878.png, Class: 4, Confidence: 0.6691362261772156
# Image: /content/datasets/bone_age/train/images/13152.png, Class: 2, Confidence: 0.8343439102172852
# Image: /content/datasets/bone_age/train/images/15368.png, Class: 6, Confidence: 0.4897879362106323
# Image: /content/datasets/bone_age/train/images/14293.png, Class: 5, Confidence: 0.7634873390197754
# Image: /content/datasets/bone_age/train/images/8738.png, Class: 4, Confidence: 0.5231068134307861
# Image: /content/datasets/bone_age/train/images/14395.png, Class: 4, Confidence: 0.7302284240722656
# Image: /content/datasets/bone_age/train/images/1434.png, Class: 3, Confidence: 0.554904580116272
# Image: /content/datasets/bone_age/train/images/11536.png, Class: 4, Confidence: 0.5507193803787231
# Image: /content/datasets/bone_age/train/images/6788.png, Class: 5, Confidence: 0.5670962929725647
# Image: /content/datasets/bone_age/train/images/3627.png, Class: 5, Confidence: 0.8693221807479858
# Image: /content/datasets/bone_age/train/images/13890.png, Class: 4, Confidence: 0.63416987657547
# Image: /content/datasets/bone_age/train/images/14539.png, Class: 5, Confidence: 0.5471044182777405
# Image: /content/datasets/bone_age/train/images/11945.png, Class: 3, Confidence: 0.777938723564148
# Image: /content/datasets/bone_age/train/images/4063.png, Class: 5, Confidence: 0.6040529608726501
# Image: /content/datasets/bone_age/train/images/2013.png, Class: 5, Confidence: 0.7999565005302429
# Image: /content/datasets/bone_age/train/images/6917.png, Class: 6, Confidence: 0.8395435214042664
# Image: /content/datasets/bone_age/train/images/5043.png, Class: 5, Confidence: 0.5688748955726624
# Image: /content/datasets/bone_age/train/images/11653.png, Class: 7, Confidence: 0.5893192887306213
# Image: /content/datasets/bone_age/train/images/7402.png, Class: 5, Confidence: 0.8581876754760742
# Image: /content/datasets/bone_age/train/images/11182.png, Class: 5, Confidence: 0.6577251553535461
# Image: /content/datasets/bone_age/train/images/8044.png, Class: 2, Confidence: 0.8319335579872131
# Image: /content/datasets/bone_age/train/images/5721.png, Class: 2, Confidence: 0.8391170501708984
# Image: /content/datasets/bone_age/train/images/9609.png, Class: 7, Confidence: 0.5620145201683044
# Image: /content/datasets/bone_age/train/images/12015.png, Class: 5, Confidence: 0.4364335536956787
# Image: /content/datasets/bone_age/train/images/14063.png, Class: 4, Confidence: 0.7448978424072266
# Image: /content/datasets/bone_age/train/images/4831.png, Class: 3, Confidence: 0.763347327709198
# Image: /content/datasets/bone_age/train/images/2935.png, Class: 6, Confidence: 0.8301240801811218
# Image: /content/datasets/bone_age/train/images/12676.png, Class: 4, Confidence: 0.6084378361701965
# Image: /content/datasets/bone_age/train/images/3720.png, Class: 4, Confidence: 0.661864697933197
# Image: /content/datasets/bone_age/train/images/3363.png, Class: 4, Confidence: 0.6138615012168884
# Image: /content/datasets/bone_age/train/images/4787.png, Class: 4, Confidence: 0.7287043929100037
# Image: /content/datasets/bone_age/train/images/11278.png, Class: 5, Confidence: 0.8141041994094849
# Image: /content/datasets/bone_age/train/images/5293.png, Class: 4, Confidence: 0.552315354347229
# Image: /content/datasets/bone_age/train/images/9945.png, Class: 5, Confidence: 0.696728527545929
# Image: /content/datasets/bone_age/train/images/13893.png, Class: 7, Confidence: 0.5827046632766724
# Image: /content/datasets/bone_age/train/images/11986.png, Class: 3, Confidence: 0.6313121318817139
# Image: /content/datasets/bone_age/train/images/15325.png, Class: 5, Confidence: 0.7805050611495972
# Image: /content/datasets/bone_age/train/images/5632.png, Class: 4, Confidence: 0.5534053444862366
# Image: /content/datasets/bone_age/train/images/5171.png, Class: 6, Confidence: 0.6837612986564636
# Image: /content/datasets/bone_age/train/images/6405.png, Class: 5, Confidence: 0.8302466869354248
# Image: /content/datasets/bone_age/train/images/10345.png, Class: 4, Confidence: 0.7131721377372742
# Image: /content/datasets/bone_age/train/images/14298.png, Class: 6, Confidence: 0.7225580215454102
# Image: /content/datasets/bone_age/train/images/3717.png, Class: 4, Confidence: 0.6667909026145935
# Image: /content/datasets/bone_age/train/images/10243.png, Class: 5, Confidence: 0.7731519937515259
# Image: /content/datasets/bone_age/train/images/14865.png, Class: 4, Confidence: 0.4156861901283264
# Image: /content/datasets/bone_age/train/images/12810.png, Class: 5, Confidence: 0.625123143196106
# Image: /content/datasets/bone_age/train/images/11447.png, Class: 2, Confidence: 0.7697986960411072
# Image: /content/datasets/bone_age/train/images/11673.png, Class: 3, Confidence: 0.6612101793289185
# Image: /content/datasets/bone_age/train/images/1668.png, Class: 4, Confidence: 0.7480015754699707
# Image: /content/datasets/bone_age/train/images/2480.png, Class: 6, Confidence: 0.8082242608070374
# Image: /content/datasets/bone_age/train/images/2852.png, Class: 3, Confidence: 0.6992233395576477
# Image: /content/datasets/bone_age/train/images/4068.png, Class: 5, Confidence: 0.7354100346565247
# Image: /content/datasets/bone_age/train/images/15484.png, Class: 4, Confidence: 0.5369561314582825
# Image: /content/datasets/bone_age/train/images/3967.png, Class: 3, Confidence: 0.7501541972160339
# Image: /content/datasets/bone_age/train/images/12705.png, Class: 5, Confidence: 0.8092512488365173
# Image: /content/datasets/bone_age/train/images/9154.png, Class: 5, Confidence: 0.32884812355041504
# Image: /content/datasets/bone_age/train/images/14597.png, Class: 5, Confidence: 0.7609269618988037
# Image: /content/datasets/bone_age/train/images/12196.png, Class: 5, Confidence: 0.7565715312957764
# Image: /content/datasets/bone_age/train/images/2758.png, Class: 6, Confidence: 0.5342927575111389
# Image: /content/datasets/bone_age/train/images/9778.png, Class: 2, Confidence: 0.8051685094833374
# Image: /content/datasets/bone_age/train/images/4974.png, Class: 4, Confidence: 0.5496928095817566
# Image: /content/datasets/bone_age/train/images/3039.png, Class: 4, Confidence: 0.7524400949478149
# Image: /content/datasets/bone_age/train/images/3527.png, Class: 5, Confidence: 0.7419843673706055
# Image: /content/datasets/bone_age/train/images/4847.png, Class: 6, Confidence: 0.5644024610519409
# Image: /content/datasets/bone_age/train/images/6413.png, Class: 1, Confidence: 0.9086678624153137
# Image: /content/datasets/bone_age/train/images/8469.png, Class: 5, Confidence: 0.6931513547897339
# Image: /content/datasets/bone_age/train/images/5393.png, Class: 4, Confidence: 0.47092512249946594
# Image: /content/datasets/bone_age/train/images/7795.png, Class: 5, Confidence: 0.82988440990448
# Image: /content/datasets/bone_age/train/images/12002.png, Class: 5, Confidence: 0.5858840346336365
# Image: /content/datasets/bone_age/train/images/6025.png, Class: 5, Confidence: 0.651972770690918
# Image: /content/datasets/bone_age/train/images/7918.png, Class: 6, Confidence: 0.5576611161231995
# Image: /content/datasets/bone_age/train/images/8622.png, Class: 2, Confidence: 0.8396614193916321
# Image: /content/datasets/bone_age/train/images/9267.png, Class: 5, Confidence: 0.7422924637794495
# Image: /content/datasets/bone_age/train/images/7658.png, Class: 5, Confidence: 0.708543598651886
# Image: /content/datasets/bone_age/train/images/7714.png, Class: 5, Confidence: 0.5123109817504883
# Image: /content/datasets/bone_age/train/images/13985.png, Class: 4, Confidence: 0.6395626068115234
# Image: /content/datasets/bone_age/train/images/1433.png, Class: 1, Confidence: 0.8186399936676025
# Image: /content/datasets/bone_age/train/images/11872.png, Class: 3, Confidence: 0.5781223177909851
# Image: /content/datasets/bone_age/train/images/8720.png, Class: 3, Confidence: 0.7198267579078674
# Image: /content/datasets/bone_age/train/images/8169.png, Class: 4, Confidence: 0.6981258988380432
# Image: /content/datasets/bone_age/train/images/5319.png, Class: 5, Confidence: 0.8509321212768555
# Image: /content/datasets/bone_age/train/images/3526.png, Class: 5, Confidence: 0.6857606172561646
# Image: /content/datasets/bone_age/train/images/1916.png, Class: 7, Confidence: 0.5296918749809265
# Image: /content/datasets/bone_age/train/images/1883.png, Class: 5, Confidence: 0.7701438069343567
# Image: /content/datasets/bone_age/train/images/7346.png, Class: 4, Confidence: 0.7792716026306152
# Image: /content/datasets/bone_age/train/images/15111.png, Class: 5, Confidence: 0.4812837243080139
# Image: /content/datasets/bone_age/train/images/5651.png, Class: 2, Confidence: 0.5624338388442993
# Image: /content/datasets/bone_age/train/images/13539.png, Class: 4, Confidence: 0.8252784609794617
# Image: /content/datasets/bone_age/train/images/13036.png, Class: 5, Confidence: 0.5687083601951599
# Image: /content/datasets/bone_age/train/images/5981.png, Class: 3, Confidence: 0.6585788130760193
# Image: /content/datasets/bone_age/train/images/7306.png, Class: 3, Confidence: 0.6291228532791138
# Image: /content/datasets/bone_age/train/images/5399.png, Class: 5, Confidence: 0.832438051700592
# Image: /content/datasets/bone_age/train/images/6286.png, Class: 1, Confidence: 0.7971339225769043
# Image: /content/datasets/bone_age/train/images/7115.png, Class: 3, Confidence: 0.7010772228240967
# Image: /content/datasets/bone_age/train/images/5216.png, Class: 3, Confidence: 0.7017344236373901
# Image: /content/datasets/bone_age/train/images/9273.png, Class: 5, Confidence: 0.8184261918067932
# Image: /content/datasets/bone_age/train/images/15292.png, Class: 4, Confidence: 0.6427038311958313
# Image: /content/datasets/bone_age/train/images/6946.png, Class: 4, Confidence: 0.5137412548065186
# Image: /content/datasets/bone_age/train/images/12043.png, Class: 7, Confidence: 0.5942363739013672
# Image: /content/datasets/bone_age/train/images/14050.png, Class: 2, Confidence: 0.839885950088501
# Image: /content/datasets/bone_age/train/images/9768.png, Class: 3, Confidence: 0.6160761713981628
# Image: /content/datasets/bone_age/train/images/15272.png, Class: 3, Confidence: 0.2944781184196472
# Image: /content/datasets/bone_age/train/images/2921.png, Class: 6, Confidence: 0.5378884673118591
# Image: /content/datasets/bone_age/train/images/2380.png, Class: 4, Confidence: 0.6377373337745667
# Image: /content/datasets/bone_age/train/images/12491.png, Class: 5, Confidence: 0.7984224557876587
# Image: /content/datasets/bone_age/train/images/2694.png, Class: 2, Confidence: 0.6066747903823853
# Image: /content/datasets/bone_age/train/images/10540.png, Class: 3, Confidence: 0.6324719190597534
# Image: /content/datasets/bone_age/train/images/5730.png, Class: 4, Confidence: 0.5958918333053589
# Image: /content/datasets/bone_age/train/images/6749.png, Class: 5, Confidence: 0.7384845614433289
# Image: /content/datasets/bone_age/train/images/2626.png, Class: 1, Confidence: 0.8267055153846741
# Image: /content/datasets/bone_age/train/images/13623.png, Class: 5, Confidence: 0.8202130794525146
# Image: /content/datasets/bone_age/train/images/10031.png, Class: 5, Confidence: 0.8159996867179871
# Image: /content/datasets/bone_age/train/images/5479.png, Class: 7, Confidence: 0.6007907390594482
# Image: /content/datasets/bone_age/train/images/13403.png, Class: 4, Confidence: 0.5992301106452942
# Image: /content/datasets/bone_age/train/images/3641.png, Class: 4, Confidence: 0.4817770719528198
# Image: /content/datasets/bone_age/train/images/8696.png, Class: 5, Confidence: 0.8688353300094604
# Image: /content/datasets/bone_age/train/images/10685.png, Class: 3, Confidence: 0.7514897584915161
# Image: /content/datasets/bone_age/train/images/7229.png, Class: 5, Confidence: 0.8356776237487793
# Image: /content/datasets/bone_age/train/images/10296.png, Class: 5, Confidence: 0.573975145816803
# Image: /content/datasets/bone_age/train/images/3083.png, Class: 5, Confidence: 0.8291366696357727
# Image: /content/datasets/bone_age/train/images/12478.png, Class: 4, Confidence: 0.7372202277183533
# Image: /content/datasets/bone_age/train/images/11027.png, Class: 2, Confidence: 0.7282927632331848
# Image: /content/datasets/bone_age/train/images/9169.png, Class: 4, Confidence: 0.7256007194519043
# Image: /content/datasets/bone_age/train/images/5251.png, Class: 4, Confidence: 0.7832457423210144
# Image: /content/datasets/bone_age/train/images/12413.png, Class: 4, Confidence: 0.7260421514511108
# Image: /content/datasets/bone_age/train/images/10662.png, Class: 4, Confidence: 0.7163790464401245
# Image: /content/datasets/bone_age/train/images/10550.png, Class: 4, Confidence: 0.5982769727706909
# Image: /content/datasets/bone_age/train/images/3301.png, Class: 3, Confidence: 0.652560293674469
# Image: /content/datasets/bone_age/train/images/11363.png, Class: 5, Confidence: 0.7954444885253906
# Image: /content/datasets/bone_age/train/images/9791.png, Class: 4, Confidence: 0.7247480750083923
# Image: /content/datasets/bone_age/train/images/9252.png, Class: 4, Confidence: 0.6689671874046326
# Image: /content/datasets/bone_age/train/images/9172.png, Class: 5, Confidence: 0.8157457709312439
# Image: /content/datasets/bone_age/train/images/2361.png, Class: 6, Confidence: 0.37828579545021057
# Image: /content/datasets/bone_age/train/images/8883.png, Class: 2, Confidence: 0.7324414253234863
# Image: /content/datasets/bone_age/train/images/11498.png, Class: 2, Confidence: 0.6998069286346436
# Image: /content/datasets/bone_age/train/images/9081.png, Class: 5, Confidence: 0.7453809380531311
# Image: /content/datasets/bone_age/train/images/7437.png, Class: 7, Confidence: 0.5714606642723083
# Image: /content/datasets/bone_age/train/images/10890.png, Class: 5, Confidence: 0.6342276930809021
# Image: /content/datasets/bone_age/train/images/9334.png, Class: 3, Confidence: 0.7262732982635498
# Image: /content/datasets/bone_age/train/images/13076.png, Class: 3, Confidence: 0.7758128046989441
# Image: /content/datasets/bone_age/train/images/7701.png, Class: 6, Confidence: 0.6562474966049194
# Image: /content/datasets/bone_age/train/images/11835.png, Class: 2, Confidence: 0.5348949432373047
# Image: /content/datasets/bone_age/train/images/5516.png, Class: 5, Confidence: 0.8147383332252502
# Image: /content/datasets/bone_age/train/images/8595.png, Class: 2, Confidence: 0.5644408464431763
# Image: /content/datasets/bone_age/train/images/8164.png, Class: 5, Confidence: 0.759120523929596
# Image: /content/datasets/bone_age/train/images/10260.png, Class: 5, Confidence: 0.6984222531318665
# Image: /content/datasets/bone_age/train/images/2845.png, Class: 2, Confidence: 0.7675613164901733
# Image: /content/datasets/bone_age/train/images/12979.png, Class: 5, Confidence: 0.7720876932144165
# Image: /content/datasets/bone_age/train/images/8444.png, Class: 4, Confidence: 0.69814133644104
# Image: /content/datasets/bone_age/train/images/9652.png, Class: 7, Confidence: 0.6046453714370728
# Image: /content/datasets/bone_age/train/images/7956.png, Class: 5, Confidence: 0.7842493653297424
# Image: /content/datasets/bone_age/train/images/1644.png, Class: 2, Confidence: 0.6033490300178528
# Image: /content/datasets/bone_age/train/images/7429.png, Class: 6, Confidence: 0.8229827284812927
# Image: /content/datasets/bone_age/train/images/13341.png, Class: 2, Confidence: 0.7342061996459961
# Image: /content/datasets/bone_age/train/images/2988.png, Class: 3, Confidence: 0.615615725517273
# Image: /content/datasets/bone_age/train/images/11830.png, Class: 4, Confidence: 0.6459658145904541
# Image: /content/datasets/bone_age/train/images/12152.png, Class: 7, Confidence: 0.5580519437789917
# Image: /content/datasets/bone_age/train/images/7805.png, Class: 2, Confidence: 0.5432454943656921
# Image: /content/datasets/bone_age/train/images/12187.png, Class: 5, Confidence: 0.774827241897583
# Image: /content/datasets/bone_age/train/images/6452.png, Class: 5, Confidence: 0.8299167156219482
# Image: /content/datasets/bone_age/train/images/10470.png, Class: 5, Confidence: 0.7467947602272034
# Image: /content/datasets/bone_age/train/images/6265.png, Class: 3, Confidence: 0.6688012480735779
# Image: /content/datasets/bone_age/train/images/11177.png, Class: 5, Confidence: 0.8482785820960999
# Image: /content/datasets/bone_age/train/images/8186.png, Class: 5, Confidence: 0.643297016620636
# Image: /content/datasets/bone_age/train/images/2905.png, Class: 4, Confidence: 0.6909026503562927
# Image: /content/datasets/bone_age/train/images/2792.png, Class: 5, Confidence: 0.8130615949630737
# Image: /content/datasets/bone_age/train/images/4579.png, Class: 5, Confidence: 0.5959146022796631
# Image: /content/datasets/bone_age/train/images/13420.png, Class: 5, Confidence: 0.5891948938369751
# Image: /content/datasets/bone_age/train/images/10791.png, Class: 5, Confidence: 0.7931281328201294
# Image: /content/datasets/bone_age/train/images/10095.png, Class: 7, Confidence: 0.6360264420509338
# Image: /content/datasets/bone_age/train/images/2227.png, Class: 5, Confidence: 0.6891869306564331
# Image: /content/datasets/bone_age/train/images/6140.png, Class: 5, Confidence: 0.7356811761856079
# Image: /content/datasets/bone_age/train/images/3877.png, Class: 4, Confidence: 0.648812472820282
# Image: /content/datasets/bone_age/train/images/12528.png, Class: 3, Confidence: 0.6816971302032471
# Image: /content/datasets/bone_age/train/images/1912.png, Class: 2, Confidence: 0.5366203784942627
# Image: /content/datasets/bone_age/train/images/3602.png, Class: 5, Confidence: 0.7535333037376404
# Image: /content/datasets/bone_age/train/images/9707.png, Class: 5, Confidence: 0.8422097563743591
# Image: /content/datasets/bone_age/train/images/9870.png, Class: 7, Confidence: 0.5576837062835693
# Image: /content/datasets/bone_age/train/images/15599.png, Class: 1, Confidence: 0.8522511720657349
# Image: /content/datasets/bone_age/train/images/11293.png, Class: 4, Confidence: 0.56608647108078
# Image: /content/datasets/bone_age/train/images/3915.png, Class: 4, Confidence: 0.6575888395309448
# Image: /content/datasets/bone_age/train/images/15059.png, Class: 5, Confidence: 0.5293251872062683
# Image: /content/datasets/bone_age/train/images/15141.png, Class: 5, Confidence: 0.680386483669281
# Image: /content/datasets/bone_age/train/images/7057.png, Class: 5, Confidence: 0.7479850053787231
# Image: /content/datasets/bone_age/train/images/2308.png, Class: 6, Confidence: 0.7936828136444092
# Image: /content/datasets/bone_age/train/images/6736.png, Class: 5, Confidence: 0.7364705801010132
# Image: /content/datasets/bone_age/train/images/8417.png, Class: 6, Confidence: 0.8194693922996521
# Image: /content/datasets/bone_age/train/images/7808.png, Class: 5, Confidence: 0.8080964684486389
# Image: /content/datasets/bone_age/train/images/5441.png, Class: 4, Confidence: 0.7603332996368408
# Image: /content/datasets/bone_age/train/images/12600.png, Class: 3, Confidence: 0.5943859219551086
# Image: /content/datasets/bone_age/train/images/14657.png, Class: 4, Confidence: 0.778430700302124
# Image: /content/datasets/bone_age/train/images/3604.png, Class: 3, Confidence: 0.7387872338294983
# Image: /content/datasets/bone_age/train/images/13310.png, Class: 6, Confidence: 0.5983982682228088
# Image: /content/datasets/bone_age/train/images/3705.png, Class: 4, Confidence: 0.5229998230934143
# Image: /content/datasets/bone_age/train/images/15187.png, Class: 5, Confidence: 0.7769699096679688
# Image: /content/datasets/bone_age/train/images/6348.png, Class: 5, Confidence: 0.7768937945365906
# Image: /content/datasets/bone_age/train/images/3017.png, Class: 5, Confidence: 0.7024100422859192
# Image: /content/datasets/bone_age/train/images/9969.png, Class: 4, Confidence: 0.5295811891555786
# Image: /content/datasets/bone_age/train/images/5616.png, Class: 4, Confidence: 0.5242872834205627
# Image: /content/datasets/bone_age/train/images/9686.png, Class: 2, Confidence: 0.8081139326095581
# Image: /content/datasets/bone_age/train/images/10346.png, Class: 4, Confidence: 0.333886057138443
# Image: /content/datasets/bone_age/train/images/15381.png, Class: 4, Confidence: 0.6348733305931091
# Image: /content/datasets/bone_age/train/images/4651.png, Class: 5, Confidence: 0.8142414093017578
# Image: /content/datasets/bone_age/train/images/11974.png, Class: 5, Confidence: 0.8398119807243347
# Image: /content/datasets/bone_age/train/images/2232.png, Class: 2, Confidence: 0.535508394241333
# Image: /content/datasets/bone_age/train/images/13095.png, Class: 6, Confidence: 0.6440829038619995
# Image: /content/datasets/bone_age/train/images/12587.png, Class: 6, Confidence: 0.6067797541618347
# Image: /content/datasets/bone_age/train/images/10113.png, Class: 5, Confidence: 0.6820793747901917
# Image: /content/datasets/bone_age/train/images/4161.png, Class: 5, Confidence: 0.8491004705429077
# Image: /content/datasets/bone_age/train/images/3353.png, Class: 2, Confidence: 0.6907297968864441
# Image: /content/datasets/bone_age/train/images/9604.png, Class: 4, Confidence: 0.6284693479537964
# Image: /content/datasets/bone_age/train/images/14232.png, Class: 5, Confidence: 0.5287930369377136
# Image: /content/datasets/bone_age/train/images/5782.png, Class: 2, Confidence: 0.5178373456001282
# Image: /content/datasets/bone_age/train/images/9389.png, Class: 5, Confidence: 0.7957702875137329
# Image: /content/datasets/bone_age/train/images/11619.png, Class: 6, Confidence: 0.5253086686134338
# Image: /content/datasets/bone_age/train/images/7414.png, Class: 4, Confidence: 0.789810836315155
# Image: /content/datasets/bone_age/train/images/9780.png, Class: 3, Confidence: 0.752412736415863
# Image: /content/datasets/bone_age/train/images/3280.png, Class: 5, Confidence: 0.8157521486282349
# Image: /content/datasets/bone_age/train/images/3329.png, Class: 5, Confidence: 0.6290692090988159
# Image: /content/datasets/bone_age/train/images/1404.png, Class: 5, Confidence: 0.6640939116477966
# Image: /content/datasets/bone_age/train/images/4678.png, Class: 5, Confidence: 0.7383902072906494
# Image: /content/datasets/bone_age/train/images/14666.png, Class: 4, Confidence: 0.7094786167144775
# Image: /content/datasets/bone_age/train/images/8168.png, Class: 6, Confidence: 0.6153178215026855
# Image: /content/datasets/bone_age/train/images/5056.png, Class: 5, Confidence: 0.8229163289070129
# Image: /content/datasets/bone_age/train/images/7559.png, Class: 4, Confidence: 0.5612485408782959
# Image: /content/datasets/bone_age/train/images/15127.png, Class: 5, Confidence: 0.5678861737251282
# Image: /content/datasets/bone_age/train/images/12055.png, Class: 2, Confidence: 0.6568641066551208
# Image: /content/datasets/bone_age/train/images/5816.png, Class: 6, Confidence: 0.853219747543335
# Image: /content/datasets/bone_age/train/images/2345.png, Class: 6, Confidence: 0.6260858178138733
# Image: /content/datasets/bone_age/train/images/7413.png, Class: 6, Confidence: 0.6306450366973877
# Image: /content/datasets/bone_age/train/images/7013.png, Class: 3, Confidence: 0.4914597272872925
# Image: /content/datasets/bone_age/train/images/3958.png, Class: 5, Confidence: 0.821017324924469
# Image: /content/datasets/bone_age/train/images/14109.png, Class: 5, Confidence: 0.5755406022071838
# Image: /content/datasets/bone_age/train/images/12235.png, Class: 5, Confidence: 0.7768245935440063
# Image: /content/datasets/bone_age/train/images/15179.png, Class: 3, Confidence: 0.5949931740760803
# Image: /content/datasets/bone_age/train/images/15094.png, Class: 5, Confidence: 0.7374463081359863
# Image: /content/datasets/bone_age/train/images/9122.png, Class: 5, Confidence: 0.7111705541610718
# Image: /content/datasets/bone_age/train/images/14065.png, Class: 6, Confidence: 0.6982051134109497
# Image: /content/datasets/bone_age/train/images/7340.png, Class: 5, Confidence: 0.7939598560333252
# Image: /content/datasets/bone_age/train/images/5606.png, Class: 4, Confidence: 0.7092263102531433
# Image: /content/datasets/bone_age/train/images/9406.png, Class: 6, Confidence: 0.8852706551551819
# Image: /content/datasets/bone_age/train/images/5006.png, Class: 2, Confidence: 0.7651646137237549
# Image: /content/datasets/bone_age/train/images/9005.png, Class: 5, Confidence: 0.6111135482788086
# Image: /content/datasets/bone_age/train/images/7220.png, Class: 5, Confidence: 0.7854253053665161
# Image: /content/datasets/bone_age/train/images/14631.png, Class: 6, Confidence: 0.6518129110336304
# Image: /content/datasets/bone_age/train/images/1933.png, Class: 6, Confidence: 0.548623263835907
# Image: /content/datasets/bone_age/train/images/4234.png, Class: 4, Confidence: 0.4495014250278473
# Image: /content/datasets/bone_age/train/images/15246.png, Class: 6, Confidence: 0.5931276679039001
# Image: /content/datasets/bone_age/train/images/14069.png, Class: 5, Confidence: 0.8337120413780212
# Image: /content/datasets/bone_age/train/images/12635.png, Class: 4, Confidence: 0.6641828417778015
# Image: /content/datasets/bone_age/train/images/14908.png, Class: 4, Confidence: 0.6934599876403809
# Image: /content/datasets/bone_age/train/images/3152.png, Class: 5, Confidence: 0.6740497946739197
# Image: /content/datasets/bone_age/train/images/13712.png, Class: 4, Confidence: 0.749735951423645
# Image: /content/datasets/bone_age/train/images/9012.png, Class: 6, Confidence: 0.837803304195404
# Image: /content/datasets/bone_age/train/images/8943.png, Class: 5, Confidence: 0.7348105907440186
# Image: /content/datasets/bone_age/train/images/7616.png, Class: 5, Confidence: 0.749383270740509
# Image: /content/datasets/bone_age/train/images/12077.png, Class: 4, Confidence: 0.6933757066726685
# Image: /content/datasets/bone_age/train/images/5329.png, Class: 2, Confidence: 0.7894620299339294
# Image: /content/datasets/bone_age/train/images/12774.png, Class: 5, Confidence: 0.7572874426841736
# Image: /content/datasets/bone_age/train/images/13965.png, Class: 5, Confidence: 0.7709949612617493
# Image: /content/datasets/bone_age/train/images/11355.png, Class: 2, Confidence: 0.7937241792678833
# Image: /content/datasets/bone_age/train/images/15404.png, Class: 5, Confidence: 0.6282254457473755
# Image: /content/datasets/bone_age/train/images/11306.png, Class: 1, Confidence: 0.7036523818969727
# Image: /content/datasets/bone_age/train/images/9224.png, Class: 3, Confidence: 0.6262468695640564
# Image: /content/datasets/bone_age/train/images/6875.png, Class: 4, Confidence: 0.7071893811225891
# Image: /content/datasets/bone_age/train/images/4167.png, Class: 2, Confidence: 0.7263526320457458
# Image: /content/datasets/bone_age/train/images/5262.png, Class: 2, Confidence: 0.5174922943115234
# Image: /content/datasets/bone_age/train/images/4322.png, Class: 4, Confidence: 0.6673793196678162
# Image: /content/datasets/bone_age/train/images/3031.png, Class: 3, Confidence: 0.6975467801094055
# Image: /content/datasets/bone_age/train/images/6772.png, Class: 3, Confidence: 0.7986340522766113
# Image: /content/datasets/bone_age/train/images/3556.png, Class: 5, Confidence: 0.8079416155815125
# Image: /content/datasets/bone_age/train/images/6341.png, Class: 3, Confidence: 0.6314671635627747
# Image: /content/datasets/bone_age/train/images/8471.png, Class: 6, Confidence: 0.7271744012832642
# Image: /content/datasets/bone_age/train/images/3509.png, Class: 5, Confidence: 0.8487389087677002
# Image: /content/datasets/bone_age/train/images/7756.png, Class: 6, Confidence: 0.7141951322555542
# Image: /content/datasets/bone_age/train/images/12789.png, Class: 3, Confidence: 0.7467407584190369
# Image: /content/datasets/bone_age/train/images/13839.png, Class: 7, Confidence: 0.5260623693466187
# Image: /content/datasets/bone_age/train/images/12296.png, Class: 7, Confidence: 0.5896309018135071
# Image: /content/datasets/bone_age/train/images/4563.png, Class: 5, Confidence: 0.6763508915901184
# Image: /content/datasets/bone_age/train/images/8378.png, Class: 2, Confidence: 0.8081014156341553
# Image: /content/datasets/bone_age/train/images/6538.png, Class: 4, Confidence: 0.48427614569664
# Image: /content/datasets/bone_age/train/images/12871.png, Class: 4, Confidence: 0.6291328072547913
# Image: /content/datasets/bone_age/train/images/2999.png, Class: 4, Confidence: 0.634966254234314
# Image: /content/datasets/bone_age/train/images/10270.png, Class: 5, Confidence: 0.8007273077964783
# Image: /content/datasets/bone_age/train/images/3663.png, Class: 5, Confidence: 0.7987418174743652
# Image: /content/datasets/bone_age/train/images/5654.png, Class: 5, Confidence: 0.7569213509559631
# Image: /content/datasets/bone_age/train/images/5886.png, Class: 2, Confidence: 0.7542997002601624
# Image: /content/datasets/bone_age/train/images/3864.png, Class: 4, Confidence: 0.6092782616615295
# Image: /content/datasets/bone_age/train/images/3023.png, Class: 3, Confidence: 0.6271454095840454
# ...
# Image: /content/datasets/bone_age/train/images/10942.png, Class: 4, Confidence: 0.715519905090332
# Image: /content/datasets/bone_age/train/images/2924.png, Class: 5, Confidence: 0.56885826587677
# Image: /content/datasets/bone_age/train/images/3346.png, Class: 5, Confidence: 0.6910802125930786
# Image: /content/datasets/bone_age/train/images/9404.png, Class: 5, Confidence: 0.700386643409729
# Image: /content/datasets/bone_age/train/images/4936.png, Class: 5, Confidence: 0.7937173247337341
# Image: /content/datasets/bone_age/train/images/7446.png, Class: 4, Confidence: 0.7620777487754822
# Image: /content/datasets/bone_age/train/images/1697.png, Class: 7, Confidence: 0.5448974370956421
# Image: /content/datasets/bone_age/train/images/8816.png, Class: 4, Confidence: 0.7047784924507141
# Image: /content/datasets/bone_age/train/images/10997.png, Class: 5, Confidence: 0.6700164675712585
# Image: /content/datasets/bone_age/train/images/11314.png, Class: 5, Confidence: 0.7317554354667664
# Image: /content/datasets/bone_age/train/images/6407.png, Class: 5, Confidence: 0.8272824287414551
# Image: /content/datasets/bone_age/train/images/4946.png, Class: 4, Confidence: 0.7164775729179382
# Image: /content/datasets/bone_age/train/images/8866.png, Class: 3, Confidence: 0.5750037431716919
# Image: /content/datasets/bone_age/train/images/11229.png, Class: 3, Confidence: 0.7219492197036743
# Image: /content/datasets/bone_age/train/images/6813.png, Class: 6, Confidence: 0.6123765707015991
# Image: /content/datasets/bone_age/train/images/11444.png, Class: 3, Confidence: 0.5497254729270935
# Image: /content/datasets/bone_age/train/images/2994.png, Class: 5, Confidence: 0.8164764642715454
# Image: /content/datasets/bone_age/train/images/2761.png, Class: 4, Confidence: 0.712081789970398
# Image: /content/datasets/bone_age/train/images/1554.png, Class: 4, Confidence: 0.7615273594856262
# Image: /content/datasets/bone_age/train/images/14724.png, Class: 3, Confidence: 0.6806901097297668
# Image: /content/datasets/bone_age/train/images/2690.png, Class: 3, Confidence: 0.3227752447128296
# Image: /content/datasets/bone_age/train/images/5966.png, Class: 4, Confidence: 0.5415987372398376
# Image: /content/datasets/bone_age/train/images/11458.png, Class: 5, Confidence: 0.750106692314148
# Image: /content/datasets/bone_age/train/images/7719.png, Class: 3, Confidence: 0.5938602685928345
# Image: /content/datasets/bone_age/train/images/15103.png, Class: 6, Confidence: 0.572216272354126
# Image: /content/datasets/bone_age/train/images/11793.png, Class: 4, Confidence: 0.7515266537666321
# Image: /content/datasets/bone_age/train/images/7265.png, Class: 5, Confidence: 0.7134679555892944
# Image: /content/datasets/bone_age/train/images/6791.png, Class: 5, Confidence: 0.8277119398117065
# Image: /content/datasets/bone_age/train/images/5988.png, Class: 5, Confidence: 0.7043143510818481
# Image: /content/datasets/bone_age/train/images/1743.png, Class: 2, Confidence: 0.6170867085456848
# Image: /content/datasets/bone_age/train/images/8057.png, Class: 3, Confidence: 0.6843137145042419
# Image: /content/datasets/bone_age/train/images/4347.png, Class: 6, Confidence: 0.5917829275131226
# Image: /content/datasets/bone_age/train/images/8867.png, Class: 3, Confidence: 0.7278668284416199
# Image: /content/datasets/bone_age/train/images/9052.png, Class: 4, Confidence: 0.6166974306106567
# Image: /content/datasets/bone_age/train/images/3291.png, Class: 4, Confidence: 0.6190136671066284
# Image: /content/datasets/bone_age/train/images/8668.png, Class: 5, Confidence: 0.6750935912132263
# Image: /content/datasets/bone_age/train/images/5162.png, Class: 7, Confidence: 0.5808447003364563
# Image: /content/datasets/bone_age/train/images/2363.png, Class: 3, Confidence: 0.5756648778915405
# Image: /content/datasets/bone_age/train/images/1992.png, Class: 2, Confidence: 0.697150707244873
# Image: /content/datasets/bone_age/train/images/14197.png, Class: 4, Confidence: 0.6044644713401794
# Image: /content/datasets/bone_age/train/images/6005.png, Class: 3, Confidence: 0.7857364416122437
# Image: /content/datasets/bone_age/train/images/10913.png, Class: 4, Confidence: 0.8609145283699036
# Image: /content/datasets/bone_age/train/images/6995.png, Class: 4, Confidence: 0.720554769039154
# Image: /content/datasets/bone_age/train/images/1592.png, Class: 1, Confidence: 0.7194606065750122
# Image: /content/datasets/bone_age/train/images/5811.png, Class: 5, Confidence: 0.526028573513031
# Image: /content/datasets/bone_age/train/images/3694.png, Class: 7, Confidence: 0.5464931726455688
# Image: /content/datasets/bone_age/train/images/2917.png, Class: 5, Confidence: 0.6728942394256592
# Image: /content/datasets/bone_age/train/images/7315.png, Class: 2, Confidence: 0.5587286353111267
# Image: /content/datasets/bone_age/train/images/9422.png, Class: 3, Confidence: 0.5969233512878418
# Image: /content/datasets/bone_age/train/images/12061.png, Class: 7, Confidence: 0.47982051968574524
# Image: /content/datasets/bone_age/train/images/11004.png, Class: 4, Confidence: 0.7033274173736572
# Image: /content/datasets/bone_age/train/images/4198.png, Class: 5, Confidence: 0.63900226354599
# Image: /content/datasets/bone_age/train/images/15377.png, Class: 4, Confidence: 0.737838089466095
# Image: /content/datasets/bone_age/train/images/11549.png, Class: 5, Confidence: 0.8041994571685791
# Image: /content/datasets/bone_age/train/images/2425.png, Class: 5, Confidence: 0.7894710898399353
# Image: /content/datasets/bone_age/train/images/10886.png, Class: 5, Confidence: 0.6969987154006958
# Image: /content/datasets/bone_age/train/images/7966.png, Class: 3, Confidence: 0.5360954999923706
# Image: /content/datasets/bone_age/train/images/12891.png, Class: 4, Confidence: 0.5562998652458191
# Image: /content/datasets/bone_age/train/images/5069.png, Class: 4, Confidence: 0.742123544216156
# Image: /content/datasets/bone_age/train/images/8479.png, Class: 2, Confidence: 0.7486217617988586
# Image: /content/datasets/bone_age/train/images/4020.png, Class: 5, Confidence: 0.8046514391899109
# Image: /content/datasets/bone_age/train/images/15147.png, Class: 4, Confidence: 0.7871213555335999
# Image: /content/datasets/bone_age/train/images/3729.png, Class: 7, Confidence: 0.5356663465499878
# Image: /content/datasets/bone_age/train/images/13497.png, Class: 5, Confidence: 0.6711304187774658
# Image: /content/datasets/bone_age/train/images/2693.png, Class: 6, Confidence: 0.7467861175537109
# Image: /content/datasets/bone_age/train/images/13832.png, Class: 2, Confidence: 0.74250328540802
# Image: /content/datasets/bone_age/train/images/8327.png, Class: 3, Confidence: 0.7557519674301147
# Image: /content/datasets/bone_age/train/images/3166.png, Class: 4, Confidence: 0.8426430225372314
# Image: /content/datasets/bone_age/train/images/7886.png, Class: 3, Confidence: 0.6915753483772278
# Image: /content/datasets/bone_age/train/images/9856.png, Class: 4, Confidence: 0.7034739851951599
# Image: /content/datasets/bone_age/train/images/8261.png, Class: 5, Confidence: 0.6035963296890259
# Image: /content/datasets/bone_age/train/images/7211.png, Class: 3, Confidence: 0.7084837555885315
# Image: /content/datasets/bone_age/train/images/12962.png, Class: 4, Confidence: 0.5477487444877625
# Image: /content/datasets/bone_age/train/images/4818.png, Class: 2, Confidence: 0.6512357592582703
# Image: /content/datasets/bone_age/train/images/11633.png, Class: 4, Confidence: 0.8219744563102722
# Image: /content/datasets/bone_age/train/images/13367.png, Class: 5, Confidence: 0.5182666778564453
# Image: /content/datasets/bone_age/train/images/10139.png, Class: 4, Confidence: 0.5534598231315613
# Image: /content/datasets/bone_age/train/images/8400.png, Class: 2, Confidence: 0.8074849843978882
# Image: /content/datasets/bone_age/train/images/14365.png, Class: 5, Confidence: 0.7812733054161072
# Image: /content/datasets/bone_age/train/images/8598.png, Class: 4, Confidence: 0.6462605595588684
# Image: /content/datasets/bone_age/train/images/2955.png, Class: 6, Confidence: 0.6886791586875916
# Image: /content/datasets/bone_age/train/images/3244.png, Class: 4, Confidence: 0.6660351157188416
# Image: /content/datasets/bone_age/train/images/8575.png, Class: 4, Confidence: 0.7858844995498657
# Image: /content/datasets/bone_age/train/images/2785.png, Class: 6, Confidence: 0.8769723773002625
# Image: /content/datasets/bone_age/train/images/10728.png, Class: 6, Confidence: 0.818351149559021
# Image: /content/datasets/bone_age/train/images/7237.png, Class: 5, Confidence: 0.5143999457359314
# Image: /content/datasets/bone_age/train/images/11905.png, Class: 4, Confidence: 0.6889816522598267
# Image: /content/datasets/bone_age/train/images/2056.png, Class: 4, Confidence: 0.591394305229187
# Image: /content/datasets/bone_age/train/images/5891.png, Class: 4, Confidence: 0.7392405867576599
# Image: /content/datasets/bone_age/train/images/7388.png, Class: 4, Confidence: 0.6566457748413086
# Image: /content/datasets/bone_age/train/images/15538.png, Class: 2, Confidence: 0.8119077086448669
# Image: /content/datasets/bone_age/train/images/8898.png, Class: 2, Confidence: 0.7698428630828857
# Image: /content/datasets/bone_age/train/images/13430.png, Class: 5, Confidence: 0.7691099047660828
# Image: /content/datasets/bone_age/train/images/6787.png, Class: 3, Confidence: 0.7597571611404419
# Image: /content/datasets/bone_age/train/images/11881.png, Class: 2, Confidence: 0.5819908976554871
# Image: /content/datasets/bone_age/train/images/10537.png, Class: 5, Confidence: 0.7606322169303894
# Image: /content/datasets/bone_age/train/images/5652.png, Class: 4, Confidence: 0.7292513251304626
# Image: /content/datasets/bone_age/train/images/12925.png, Class: 3, Confidence: 0.5877686142921448
# Image: /content/datasets/bone_age/train/images/2428.png, Class: 6, Confidence: 0.5631809234619141
# Image: /content/datasets/bone_age/train/images/7208.png, Class: 5, Confidence: 0.7136228680610657
# Image: /content/datasets/bone_age/train/images/12567.png, Class: 2, Confidence: 0.6553479433059692
# Image: /content/datasets/bone_age/train/images/1452.png, Class: 6, Confidence: 0.6925423741340637
# Image: /content/datasets/bone_age/train/images/3844.png, Class: 5, Confidence: 0.6648649573326111
# Image: /content/datasets/bone_age/train/images/7286.png, Class: 4, Confidence: 0.8376917243003845
# Image: /content/datasets/bone_age/train/images/12226.png, Class: 4, Confidence: 0.6317607164382935
# Image: /content/datasets/bone_age/train/images/3081.png, Class: 2, Confidence: 0.8041308522224426
# Image: /content/datasets/bone_age/train/images/11934.png, Class: 4, Confidence: 0.6318054795265198
# Image: /content/datasets/bone_age/train/images/12639.png, Class: 5, Confidence: 0.7896895408630371
# Image: /content/datasets/bone_age/train/images/8259.png, Class: 5, Confidence: 0.5316875576972961
# Image: /content/datasets/bone_age/train/images/8777.png, Class: 5, Confidence: 0.8189178705215454
# Image: /content/datasets/bone_age/train/images/9747.png, Class: 6, Confidence: 0.591458261013031
# Image: /content/datasets/bone_age/train/images/6063.png, Class: 4, Confidence: 0.6147621870040894
# Image: /content/datasets/bone_age/train/images/7114.png, Class: 5, Confidence: 0.7252984642982483
# Image: /content/datasets/bone_age/train/images/4013.png, Class: 4, Confidence: 0.6465328335762024
# Image: /content/datasets/bone_age/train/images/8343.png, Class: 3, Confidence: 0.7698574662208557
# Image: /content/datasets/bone_age/train/images/15041.png, Class: 6, Confidence: 0.8383055925369263
# Image: /content/datasets/bone_age/train/images/15369.png, Class: 2, Confidence: 0.6573545336723328
# Image: /content/datasets/bone_age/train/images/7368.png, Class: 2, Confidence: 0.83319491147995
# Image: /content/datasets/bone_age/train/images/6182.png, Class: 7, Confidence: 0.4898807406425476
# Image: /content/datasets/bone_age/train/images/5309.png, Class: 5, Confidence: 0.595708429813385
# Image: /content/datasets/bone_age/train/images/7304.png, Class: 4, Confidence: 0.475423127412796
# Image: /content/datasets/bone_age/train/images/10811.png, Class: 5, Confidence: 0.71439528465271
# Image: /content/datasets/bone_age/train/images/5809.png, Class: 6, Confidence: 0.828710675239563
# Image: /content/datasets/bone_age/train/images/1514.png, Class: 4, Confidence: 0.6509720683097839
# Image: /content/datasets/bone_age/train/images/4755.png, Class: 6, Confidence: 0.6855449676513672
# Image: /content/datasets/bone_age/train/images/13503.png, Class: 3, Confidence: 0.6897145509719849
# Image: /content/datasets/bone_age/train/images/5129.png, Class: 5, Confidence: 0.8480262756347656
# Image: /content/datasets/bone_age/train/images/8558.png, Class: 6, Confidence: 0.7831997275352478
# Image: /content/datasets/bone_age/train/images/12791.png, Class: 5, Confidence: 0.4624265432357788
# Image: /content/datasets/bone_age/train/images/10769.png, Class: 4, Confidence: 0.6945265531539917
# Image: /content/datasets/bone_age/train/images/7578.png, Class: 7, Confidence: 0.621220052242279
# Image: /content/datasets/bone_age/train/images/7947.png, Class: 4, Confidence: 0.6251382231712341
# Image: /content/datasets/bone_age/train/images/7895.png, Class: 1, Confidence: 0.6812607049942017
# Image: /content/datasets/bone_age/train/images/12747.png, Class: 5, Confidence: 0.7004360556602478
# Image: /content/datasets/bone_age/train/images/3934.png, Class: 4, Confidence: 0.6704472899436951
# Image: /content/datasets/bone_age/train/images/6956.png, Class: 3, Confidence: 0.5672928094863892
# Image: /content/datasets/bone_age/train/images/1476.png, Class: 4, Confidence: 0.7063175439834595
# Image: /content/datasets/bone_age/train/images/5636.png, Class: 4, Confidence: 0.6282835006713867
# Image: /content/datasets/bone_age/train/images/3634.png, Class: 4, Confidence: 0.6104174256324768
# Image: /content/datasets/bone_age/train/images/12072.png, Class: 5, Confidence: 0.5999792814254761
# Image: /content/datasets/bone_age/train/images/14092.png, Class: 2, Confidence: 0.8361455798149109
# Image: /content/datasets/bone_age/train/images/11733.png, Class: 5, Confidence: 0.6811303496360779
# Image: /content/datasets/bone_age/train/images/6973.png, Class: 5, Confidence: 0.6815099716186523
# Image: /content/datasets/bone_age/train/images/6781.png, Class: 7, Confidence: 0.6132737398147583
# Image: /content/datasets/bone_age/train/images/4304.png, Class: 5, Confidence: 0.752788245677948
# Image: /content/datasets/bone_age/train/images/8721.png, Class: 5, Confidence: 0.8525795936584473
# Image: /content/datasets/bone_age/train/images/14454.png, Class: 2, Confidence: 0.8027426600456238
# Image: /content/datasets/bone_age/train/images/3321.png, Class: 5, Confidence: 0.7159279584884644
# Image: /content/datasets/bone_age/train/images/3033.png, Class: 5, Confidence: 0.5596976280212402
# Image: /content/datasets/bone_age/train/images/3904.png, Class: 2, Confidence: 0.727034330368042
# Image: /content/datasets/bone_age/train/images/13395.png, Class: 4, Confidence: 0.5199165940284729
# Image: /content/datasets/bone_age/train/images/13816.png, Class: 4, Confidence: 0.6611559391021729
# Image: /content/datasets/bone_age/train/images/15567.png, Class: 5, Confidence: 0.7131316065788269
# Image: /content/datasets/bone_age/train/images/13063.png, Class: 5, Confidence: 0.8542946577072144
# Image: /content/datasets/bone_age/train/images/12873.png, Class: 4, Confidence: 0.7655239105224609
# Image: /content/datasets/bone_age/train/images/8628.png, Class: 6, Confidence: 0.8636302947998047
# Image: /content/datasets/bone_age/train/images/2161.png, Class: 3, Confidence: 0.574068546295166
# Image: /content/datasets/bone_age/train/images/8367.png, Class: 5, Confidence: 0.6305534243583679
# Image: /content/datasets/bone_age/train/images/4664.png, Class: 4, Confidence: 0.44956550002098083
# Image: /content/datasets/bone_age/train/images/10038.png, Class: 5, Confidence: 0.8610918521881104
# Image: /content/datasets/bone_age/train/images/5334.png, Class: 6, Confidence: 0.8110336065292358
# Image: /content/datasets/bone_age/train/images/10290.png, Class: 2, Confidence: 0.7775479555130005

# %%
import json
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from PIL import Image

# dataset class for classification with confidence
class ClassificationWithConfidenceDataset(Dataset):
    def __init__(self, img_dir, label_dir, pred_file, transform=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        with open(pred_file, 'r') as f:
            self.predictions = json.load(f)
        self.img_files = list(self.predictions.keys())
        self.transform = transform

    def __len__(self):
        return len(self.img_files)

    def __getitem__(self, idx):
        img_path = self.img_files[idx]
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        pred_info = self.predictions[img_path]
        pred_class = pred_info['class']
        confidence = pred_info['confidence']

        # Get the actual label
        label_file = os.path.join(self.label_dir, os.path.basename(img_path).replace('.png', '.txt'))
        with open(label_file, 'r') as f:
            actual_class = int(f.readline().strip().split()[0])

        return image, actual_class, torch.tensor(confidence, dtype=torch.float32)


train_images_dir = '/content/datasets/bone_age/train/images'
train_label_dir = '/content/datasets/bone_age/train/labels'
pred_file = '/content/train_image_predictions_mapping.json'


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


train_dataset = ClassificationWithConfidenceDataset(train_images_dir, train_label_dir, pred_file, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
class ClassifierWithConfidence(nn.Module):
    def __init__(self, num_classes):
        super(ClassifierWithConfidence, self).__init__()
        self.cnn = models.resnet18(weights='ResNet18_Weights.DEFAULT')
        num_ftrs = self.cnn.fc.in_features
        self.cnn.fc = nn.Identity()  # Remove the last fully connected layer
        self.fc1 = nn.Linear(num_ftrs + 1, 256)  # Adding one for the confidence score
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x, confidence):
        x = self.cnn(x)
        x = torch.cat((x, confidence.unsqueeze(1)), dim=1)  # Concatenate the confidence score
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x


num_classes = 9
model = ClassifierWithConfidence(num_classes)
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)


num_epochs = 10
device = 'cuda' if torch.cuda.is_available() else 'cpu'

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for images, labels, confidences in train_loader:
        images, labels, confidences = images.to(device), labels.to(device), confidences.to(device)

        optimizer.zero_grad()

        outputs = model(images, confidences)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader)}")

# Save the trained model
torch.save(model.state_dict(), "classifier_model_with_confidence.pth")
print("Classifier model saved to classifier_model_with_confidence.pth")

# %%
import json
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from PIL import Image
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class ClassificationDataset(Dataset):
    def __init__(self, img_dir, label_dir, transform=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.img_files = [os.path.join(img_dir, fname) for fname in os.listdir(img_dir) if fname.endswith('.png')]
        self.transform = transform

    def __len__(self):
        return len(self.img_files)

    def __getitem__(self, idx):
        img_path = self.img_files[idx]
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        # Get the actual label
        label_file = os.path.join(self.label_dir, os.path.basename(img_path).replace('.png', '.txt'))
        with open(label_file, 'r') as f:
            actual_class = int(f.readline().strip().split()[0])

        return image, actual_class


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_images_dir = '/content/datasets/bone_age/val/images'
test_label_dir = '/content/datasets/bone_age/val/labels'

test_dataset = ClassificationDataset(test_images_dir, test_label_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)


model.eval()
all_labels_test = []
all_preds_test = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images, torch.zeros(len(images)).to(device))  # Zero confidence for testing
        _, preds = torch.max(outputs, 1)
        all_labels_test.extend(labels.cpu().numpy())
        all_preds_test.extend(preds.cpu().numpy())


test_conf_matrix = confusion_matrix(all_labels_test, all_preds_test)
print(f"Test Confusion Matrix:\n{test_conf_matrix}")


def plot_confusion_matrix(conf_matrix, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()


class_names = [str(i) for i in range(num_classes)]
plot_confusion_matrix(test_conf_matrix, class_names)

# %% [markdown]
# Model Without Distillation

# %%
import json
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from PIL import Image
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


class ClassificationDataset(Dataset):
    def __init__(self, img_dir, label_dir, transform=None):
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.img_files = [os.path.join(img_dir, fname) for fname in os.listdir(img_dir) if fname.endswith('.png')]
        self.transform = transform

    def __len__(self):
        return len(self.img_files)

    def __getitem__(self, idx):
        img_path = self.img_files[idx]
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        # Get the actual label
        label_file = os.path.join(self.label_dir, os.path.basename(img_path).replace('.png', '.txt'))
        with open(label_file, 'r') as f:
            actual_class = int(f.readline().strip().split()[0])

        return image, actual_class


train_images_dir = '/content/datasets/bone_age/train/images'
train_label_dir = '/content/datasets/bone_age/train/labels'
val_images_dir = '/content/datasets/bone_age/val/images'
val_label_dir = '/content/datasets/bone_age/val/labels'


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


train_dataset = ClassificationDataset(train_images_dir, train_label_dir, transform=transform)
val_dataset = ClassificationDataset(val_images_dir, val_label_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


class ClassifierWithoutConfidence(nn.Module):
    def __init__(self, num_classes):
        super(ClassifierWithoutConfidence, self).__init__()
        self.cnn = models.resnet18(weights='ResNet18_Weights.DEFAULT')
        num_ftrs = self.cnn.fc.in_features
        self.cnn.fc = nn.Linear(num_ftrs, num_classes)  # Fully connected layer for classification

    def forward(self, x):
        x = self.cnn(x)
        return x


num_classes = 9
model = ClassifierWithoutConfidence(num_classes)
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')


criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)


num_epochs = 10
device = 'cuda' if torch.cuda.is_available() else 'cpu'

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    all_labels_train = []
    all_preds_train = []

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        all_labels_train.extend(labels.cpu().numpy())
        all_preds_train.extend(preds.cpu().numpy())

    train_conf_matrix = confusion_matrix(all_labels_train, all_preds_train)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader)}")
    print(f"Training Confusion Matrix:\n{train_conf_matrix}")


model.eval()
all_labels_val = []
all_preds_val = []
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_labels_val.extend(labels.cpu().numpy())
        all_preds_val.extend(preds.cpu().numpy())

val_conf_matrix = confusion_matrix(all_labels_val, all_preds_val)
print(f"Validation Confusion Matrix:\n{val_conf_matrix}")


def plot_confusion_matrix(conf_matrix, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()


class_names = [str(i) for i in range(num_classes)]
plot_confusion_matrix(val_conf_matrix, class_names)


torch.save(model.state_dict(), "classifier_model_without_confidence.pth")
print("Classifier model saved to classifier_model_without_confidence.pth")

# %% [markdown]
# Evaluate on Poisoned Data

# %%
import torch
import torch.nn as nn
from torchvision import models


class ClassifierWithConfidence(nn.Module):
    def __init__(self, num_classes):
        super(ClassifierWithConfidence, self).__init__()
        self.cnn = models.resnet18(weights='ResNet18_Weights.DEFAULT')
        num_ftrs = self.cnn.fc.in_features
        self.cnn.fc = nn.Identity()
        self.fc1 = nn.Linear(num_ftrs + 1, 256)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x, confidence):
        x = self.cnn(x)
        x = torch.cat((x, confidence.unsqueeze(1)), dim=1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x


num_classes = 9
model = ClassifierWithConfidence(num_classes)


model_path = '/content/classifier_model_with_confidence.pth'

# Load the state dictionary
state_dict = torch.load(model_path)


model.load_state_dict(state_dict)


device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

# %%
import os
import shutil

image_dir = '/content/datasets/bone_age/train/adversarial_images'
original_label_dir = '/content/datasets/bone_age/train/labels'
adversarial_label_dir = '/content/datasets/bone_age/train/adversarial_labels'


os.makedirs(adversarial_label_dir, exist_ok=True)

# Iterate through each image file in the adversarial image directory
for image_file in os.listdir(image_dir):
    if image_file.endswith('.png'):

        base_name = os.path.splitext(image_file)[0]


        original_label_file = os.path.join(original_label_dir, f"{base_name}.txt")
        adversarial_label_file = os.path.join(adversarial_label_dir, f"{base_name}.txt")

        if os.path.isfile(original_label_file):
            shutil.copyfile(original_label_file, adversarial_label_file)
            print(f"Copied label for {image_file} to adversarial labels directory.")
        else:
            print(f"Original label file for {image_file} does not exist.")

print(f"All matching label files have been copied to {adversarial_label_dir}.")

# %%
import torch
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


model = YOLO("runs/detect/train/weights/best.pt")
model.model.to(device)  # Ensure the model's weights are moved to GPU if available

# directory containing original images and ground truth labels
original_image_dir = '/content/datasets/bone_age/train/images'
ground_truth_labels_dir = '/content/datasets/bone_age/train/labels'
# Path to save adversarial images
adv_image_dir = '/content/datasets/bone_age/train/adversarial_images'


if not os.path.exists(original_image_dir):
    raise FileNotFoundError(f"Original image directory does not exist: {original_image_dir}")
if not os.path.exists(ground_truth_labels_dir):
    raise FileNotFoundError(f"Ground truth labels directory does not exist: {ground_truth_labels_dir}")
if not os.path.exists(adv_image_dir):
    os.makedirs(adv_image_dir)


transform = transforms.Compose([
    transforms.Resize((416, 416)),
    transforms.ToTensor(),
])

#  dataset class to handle images without class folders
class OriginalDataset(Dataset):
    def __init__(self, image_dir, label_dir, transform=None):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.transform = transform
        self.image_names = os.listdir(image_dir)

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        img_path = os.path.join(self.image_dir, img_name)
        label_path = os.path.join(self.label_dir, img_name.replace('.png', '.txt'))

        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        labels = self.load_labels(label_path)
        return image, labels, img_name

    @staticmethod
    def load_labels(label_path):
        with open(label_path, 'r') as f:
            labels = f.readlines()
        labels = [list(map(float, label.strip().split())) for label in labels]
        return labels

# original dataset
original_dataset = OriginalDataset(original_image_dir, ground_truth_labels_dir, transform=transform)
data_loader = DataLoader(original_dataset, batch_size=1, shuffle=False)

# apply C&W attack on an image
def cw_attack(model, images, device, c=1e-4, kappa=0, steps=1000, lr=0.01):
    images = images.to(device)

    perturbed_images = images.clone().detach().requires_grad_(True).to(device)
    optimizer = torch.optim.Adam([perturbed_images], lr=lr)

    for step in range(steps):
        optimizer.zero_grad()

        outputs = model(perturbed_images)
        # loss calculation to suit YOLO output format
        loss = -outputs[0][..., 5:].max()  # Use the max class score
        loss.backward()

        optimizer.step()

        # Clip the perturbed images to ensure they are within [0, 1]
        perturbed_images.data = torch.clamp(perturbed_images, 0, 1)

    return perturbed_images

# Generate adversarial examples and save them
for img, ground_truth, img_name in data_loader:
    # Ensure img_name is a string
    if isinstance(img_name, tuple):
        img_name = img_name[0]

    adv_img_path = os.path.join(adv_image_dir, img_name)
    if os.path.exists(adv_img_path):
        continue

    img = img.to(device)

    # Generate adversarial example using C&W attack
    perturbed_img = cw_attack(model.model, img, device)

    # Save the adversarial image
    adv_image_np = perturbed_img.squeeze().detach().cpu().numpy().transpose(1, 2, 0) * 255
    adv_image_np = adv_image_np.astype(np.uint8)
    adv_image = Image.fromarray(adv_image_np)
    adv_image.save(adv_img_path)

print("Adversarial images generated and saved.")

# %%
test_images_dir = '/content/datasets/bone_age/train/adversarial_images'
test_label_dir = '/content/datasets/bone_age/train/adversarial_labels'

test_dataset = ClassificationDataset(test_images_dir, test_label_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

model.eval()
all_labels_test = []
all_preds_test = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images, torch.zeros(len(images)).to(device))
        _, preds = torch.max(outputs, 1)
        all_labels_test.extend(labels.cpu().numpy())
        all_preds_test.extend(preds.cpu().numpy())


test_conf_matrix = confusion_matrix(all_labels_test, all_preds_test)
print(f"Test Confusion Matrix:\n{test_conf_matrix}")


def plot_confusion_matrix(conf_matrix, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()


class_names = [str(i) for i in range(num_classes)]  # Replace with actual class names if available
plot_confusion_matrix(test_conf_matrix, class_names)

# %%
import json
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from PIL import Image
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


class ClassifierWithoutConfidence(nn.Module):
    def __init__(self, num_classes):
        super(ClassifierWithoutConfidence, self).__init__()
        self.cnn = models.resnet18(weights='ResNet18_Weights.DEFAULT')
        num_ftrs = self.cnn.fc.in_features
        self.cnn.fc = nn.Linear(num_ftrs, num_classes)  # Fully connected layer for classification

    def forward(self, x):
        x = self.cnn(x)
        return x


num_classes = 9
model = ClassifierWithoutConfidence(num_classes)


model_path = '/content/classifier_model_without_confidence.pth'

# Load the state dictionary
state_dict = torch.load(model_path)


model.load_state_dict(state_dict)

# Move the model to the appropriate device (CPU or GPU)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

# %%
test_images_dir = '/content/datasets/bone_age/train/adversarial_images'
test_label_dir = '/content/datasets/bone_age/train/adversarial_labels'

test_dataset = ClassificationDataset(test_images_dir, test_label_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

model.eval()
all_labels_test = []
all_preds_test = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_labels_test.extend(labels.cpu().numpy())
        all_preds_test.extend(preds.cpu().numpy())


test_conf_matrix = confusion_matrix(all_labels_test, all_preds_test)
print(f"Test Confusion Matrix:\n{test_conf_matrix}")

def plot_confusion_matrix(conf_matrix, class_names):
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()


class_names = [str(i) for i in range(num_classes)]
plot_confusion_matrix(test_conf_matrix, class_names)
